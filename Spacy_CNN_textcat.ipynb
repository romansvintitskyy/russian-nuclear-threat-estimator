# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Hyperparameters 

threat_path = '.../nuclear_threat.csv'

by_column = "text" #choose a column on which the data will be trained: "text", "text-medium", "text-short"
side = 'r' # w -- West, r -- Russia
assume = ('W', 'E') #must be a tuple of (label_to_change, suggested_label_instead). "W" -- Warning, "E" -- Escalatory, "D" -- De-escalatory

to_expand = True #if True -- trained sentence-wise
n_epochs = 10 #no. of epochs that model will be trained on
test_on = by_column

# %% [markdown]
# #Expand Data

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_text(text):
    # Tokenize the text into words
    tokens = word_tokenize(text.lower())
    
    # Remove punctuation
    tokens = [token for token in tokens if token not in string.punctuation]
    
    # Remove stop words
    stop_words = set(stopwords.words('english')).difference({"not", "no"})
    tokens = [token for token in tokens if token not in stop_words]
    
    # Lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    return " ".join(tokens)

# Example usage
text = "Hello, how not are you doing today? I hope everything is going well!"
preprocessed_text = preprocess_text(text)
print(preprocessed_text)
# Out:
# hello not today hope everything going well
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def expand(data, type, side=None, binary_assumption=None, sent_level = to_expand):
  expanded_data = pd.DataFrame(columns=data.columns)

  if sent_level:
    #if sent_level is True, then we will split the text in a given cell
    #into sentences and split one row into multiple rows of corresponding values
    
    for index, row in data.iterrows():
        text = row[type]
        label = row["label"]
        
        # Split the text into sentences
        sentences = text.split(".")
        
        # Create a new row for each sentence
        for sentence in sentences:
            if sentence.strip() != "":
                sentence = preprocess_text(sentence)
                expanded_data = pd.concat([expanded_data, pd.DataFrame({**row, type: sentence.strip()}, index=[0])], ignore_index=True)
  else:
    expanded_data = data

  if side:
    expanded_data = expanded_data[expanded_data['side'] == side]
  if binary_assumption:
    prev_label, new_label = binary_assumption[0], binary_assumption[1]
    expanded_data.loc[expanded_data['label'] == prev_label, 'label'] = new_label
  return expanded_data

# %% [markdown]
# # Text Classification with SpaCy

# %%
from tkinter.constants import N
import pandas as pd

nuclear_threat = pd.read_csv(threat_path)
nuclear_threat = expand(nuclear_threat, by_column, side, binary_assumption=assume, sent_level=to_expand)
len(nuclear_threat)
# Out:
# 3188

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Splitting the DataFrame into train and test sets
nuclear_threat_train, nuclear_threat_test = train_test_split(nuclear_threat, test_size=0.1, random_state=40)

print("Train DataFrame:")
print(len(nuclear_threat_train))
print("\nTest DataFrame:")
print(len(nuclear_threat_test))
nuclear_threat_test
# Out:
# Train DataFrame:
# 2869
#
# Test DataFrame:
# 319
#             date                                               text  \
# 4967  2022-04-25  better time comprehensive project within russi...
# 686   2022-02-22  later began assure u accession nato central ea...
# 3256  2022-03-16  focus protecting mother child supporting famil...
# 2     2022-01-27  no need review russia ’ nuclear doctrine docum...
# 3140  2022-03-16            rendered aid simply could not otherwise
# ...          ...                                                ...
# 5691  2022-04-29  `` massacre civilian bucha lavrov reply `` mar...
# 6588  2022-08-05  26 october 2020 president russian federation v...
# 5692  2022-04-29  mayor bucha declared victory saying bucha retu...
# 1968  2022-03-03                        cia extensive presence time
# 448   2022-02-22  speaking directly today not explain happening ...
#
#                                             text-medium  \
# 4967  In a lengthy April 25 interview, Lavrov somewh...
# 686   In a televised address on February 21, Putin a...
# 3256  Russian rhetoric, meanwhile, remained aggressi...
# 2     A month before the invasion, the Russian leade...
# 3140  Russian rhetoric, meanwhile, remained aggressi...
# ...                                                 ...
# 5691  The same day, April 29, Lavrov qualified his e...
# 6588  On August 5, Russia reiterated the defensive n...
# 5692  The same day, April 29, Lavrov qualified his e...
# 1968  On March 2, Russian Foreign Ministry spokeswom...
# 448   In a televised address on February 21, Putin a...
#
#                                              text-short side label comment
# 4967  Lavrov: The risks of nuclear war are “very sig...    r     E     NaN
# 686   Putin: Ukraine is seeking to acquire tactical ...    r     E     NaN
# 3256   Putin: The West wants to “finish off” Russia,...    r     E     NaN
# 2     Medvedev: Russia has “the right” to use nuclea...    r     E     NaN
# 3140   Putin: The West wants to “finish off” Russia,...    r     E     NaN
# ...                                                 ...  ...   ...     ...
# 5691   Lavrov: Russian policymakers are “champions o...    r     D     NaN
# 6588  Russia’s nuclear policy is “aimed exclusively ...    r     D     NaN
# 5692   Lavrov: Russian policymakers are “champions o...    r     D     NaN
# 1968   Lavrov: Thought of nuclear war is on Western,...    r     D     NaN
# 448   Putin: Ukraine is seeking to acquire tactical ...    r     E     NaN
#
# [319 rows x 7 columns]

# %% [markdown]
# # Building a Bag of Words model

# %%
import spacy
# Create an empty model
nlp = spacy.blank("en")

# %%
if assume:
  #binary classification
  # Add the TextCategorizer to the empty model
  textcat = nlp.add_pipe("textcat")
  # Add labels to text classifier
  textcat.add_label("E")
  textcat.add_label("D")
else:
  #multiple labels
  textcat = nlp.add_pipe("textcat_multilabel")
  textcat.add_label("E")
  textcat.add_label("D")
  textcat.add_label("W")

# %% [markdown]
# # Training a Text Categorizer Model

# %%
train_texts = nuclear_threat_train[by_column].values
if assume:
  train_labels = [{'cats': {'E': label == 'E',
                            'D': label == 'D'}} 
                  for label in nuclear_threat_train['label']]
else:
  train_labels = [{'cats': {'E': label == 'E',
                          'D': label == 'D', 'W':label == 'W'}} 
                for label in nuclear_threat_train['label']]

# %% [markdown]
# Then we combine the texts and labels into a single list.

# %%
train_data = list(zip(train_texts, train_labels))
train_data[:10]
# Out:
# [('regard question rhetorical', {'cats': {'E': False, 'D': True}}),
#  ('question short still chose read piece paper',
#   {'cats': {'E': False, 'D': True}}),
#  ('always remember', {'cats': {'E': True, 'D': False}}),
#  ('policy confrontation', {'cats': {'E': True, 'D': False}}),
#  ('enticing ukraine idea one day country become part west defeat putin',
#   {'cats': {'E': False, 'D': True}}),
#  ('would like point situation not considered separately development past 30 year full various event relation russia west west rest world particular united state',
#   {'cats': {'E': False, 'D': True}}),
#  ('experience serve good lesson u shown u paralysis power first step towards complete degradation oblivion',
#   {'cats': {'E': True, 'D': False}}),
#  ('ten year ago', {'cats': {'E': True, 'D': False}}),
#  ('domestic sourcing not complete achieve mean',
#   {'cats': {'E': True, 'D': False}}),
#  ('not ignore thing either especially know so-called west act regard russia',
#   {'cats': {'E': True, 'D': False}})]

# %%
from spacy.util import minibatch
from spacy.training.example import Example

spacy.util.fix_random_seed(1)
optimizer = nlp.begin_training()

# Create the batch generator with batch size = 8
batches = minibatch(train_data, size=8)
# Iterate through minibatches
for batch in batches:
    # Each batch is a list of (text, label) 
    for text, labels in batch:
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, labels)
        nlp.update([example], sgd=optimizer)

# %% [markdown]
# This is just one training loop (or epoch) through the data. The model will typically need multiple epochs. Use another loop for more epochs, and optionally re-shuffle the training data at the begining of each loop.

# %%
import random

random.seed(1)
spacy.util.fix_random_seed(1)
optimizer = nlp.begin_training()

losses = {}
for epoch in range(n_epochs):
    random.shuffle(train_data)
    # Create the batch generator with batch size = 8
    batches = minibatch(train_data, size=8)
    # Iterate through minibatches
    for batch in batches:
        for text, labels in batch:
            doc = nlp.make_doc(text)
            example = Example.from_dict(doc, labels)
            nlp.update([example], sgd=optimizer, losses=losses)
    print(losses)
# Out:
# {'textcat': 619.4779936905276}
# {'textcat': 1176.695700145588}
# {'textcat': 1561.2454800420169}
# {'textcat': 1813.8168988087452}
# {'textcat': 1970.361529583255}
# {'textcat': 2076.159996243773}
# {'textcat': 2167.188737259952}
# {'textcat': 2252.380002380052}
# {'textcat': 2309.943610894378}
# {'textcat': 2374.368548135213}

# %% [markdown]
# # Making Predictions

# %%
texts = nuclear_threat_test[test_on]
docs = [nlp.tokenizer(text) for text in texts]

# Use textcat to get the scores for each doc
if assume:
  textcat = nlp.get_pipe('textcat')
else:
  textcat = nlp.get_pipe('textcat_multilabel')
scores = textcat.predict(docs)

# %% [markdown]
# The scores are used to predict a single class or label by choosing the label with the highest probability. You get the index of the highest probability with `scores.argmax`, then use the index to get the label string from `textcat.labels`.

# %%
# From the scores, find the label with the highest score/probability
predicted_labels = scores.argmax(axis=1)
predicted_labels = [textcat.labels[label] for label in predicted_labels]

# %% [markdown]
# Examples

# %%
# texts = ["russia has a right for defensive nuclear alert"]
# docs = [nlp.tokenizer(text) for text in texts]
    
# # Use textcat to get the scores for each doc
# textcat = nlp.get_pipe('textcat')
# scores = textcat.predict(docs)
# # From the scores, find the label with the highest score/probability
# predicted_labels = scores.argmax(axis=1)
# predicted_labels = [textcat.labels[label] for label in predicted_labels]
# predicted_labels

# %% [markdown]
# #Evaluation. Confusion matrix

# %%
labels_test = list(nuclear_threat_test['label'])
len(labels_test)
# Out:
# 319

# %%
tp = 0
tn = 0
fp = 0
fn = 0

for i in range(len(labels_test)):
  print(40*"-")
  print("Event ", i, predicted_labels[i], labels_test[i])
  if predicted_labels[i] == "E" and labels_test[i] == "E":
    tp += 1
    print("TP")
  if predicted_labels[i] != "E" and labels_test[i] != "E":
    tn += 1
    print("TN")
  if predicted_labels[i] == "E" and labels_test[i] != "E":
    fp += 1
    print("FP")
  if predicted_labels[i] != "E" and labels_test[i] == "E":
    fn += 1
    print("FN")
  print(docs[i])
tp, tn, fp, fn
# Out:
# ----------------------------------------
# Event  0 E E
# TP
# better time comprehensive project within russia-nato council work together promote settlement afghanistan
# ----------------------------------------
# Event  1 E E
# TP
# later began assure u accession nato central eastern european country would improve relation moscow relieve country fear steeped bitter historical legacy even create belt country friendly towards russia
# ----------------------------------------
# Event  2 E E
# TP
# focus protecting mother child supporting family child
# ----------------------------------------
# Event  3 E E
# TP
# no need review russia ’ nuclear doctrine document make possible achieve various goal deputy chairman russian security council dmitry medvedev said interview russian medium outlet including ta
# ----------------------------------------
# Event  4 E E
# TP
# rendered aid simply could not otherwise
# ----------------------------------------
# Event  5 D D
# TN
# far could putin go concern mass mobilization could accompanied introduction martial law russia move would confer extraordinary power putin enabling dramatic increase control citizen ’ life russia ’ economy
# ----------------------------------------
# Event  6 E E
# TP
# looked pleased see kronstadt face face face dam construction completed great assistance period
# ----------------------------------------
# Event  7 E E
# TP
# lukashenko yes absolutely agree
# ----------------------------------------
# Event  8 E E
# TP
# everything purpose accepted humiliating treaty brest-litovsk although military economic situation kaiser germany ally dramatic outcome first world war foregone conclusion satisfied demand wish nationalist within country
# ----------------------------------------
# Event  9 D D
# TN
# heard salisbury poisoning heard attempted assassination russian opposition leader alexei navalny 're hearing
# ----------------------------------------
# Event  10 E E
# TP
# colleague clearly ongoing development drawing line global dominance western country politics economy
# ----------------------------------------
# Event  11 D E
# FN
# potentially pose threat existence humanity '' medvedev serf deputy chairman russian security council said telegram
# ----------------------------------------
# Event  12 E E
# TP
# ” finally “ republic ussr shall citizenship shall apply resident
# ----------------------------------------
# Event  13 D D
# TN
# west strengthening security expense russia ’ security become proverbial
# ----------------------------------------
# Event  14 D D
# TN
# time remains seen whether united state change deliberately destructive course whether ready engage dialogue basis equality take account interest security concern working together create foundation new stable architecture international security
# ----------------------------------------
# Event  15 D D
# TN
# military leader including defense secretary lloyd austin joint chief staff chair general mark
# ----------------------------------------
# Event  16 E D
# FP
# talk defensive character alliance cheap talk “ favour poor ” say
# ----------------------------------------
# Event  17 E D
# FP
# fact within framework minsk agreement signed
# ----------------------------------------
# Event  18 E E
# TP
# extremely undesirable potentially dangerous scenario '' said
# ----------------------------------------
# Event  19 E E
# TP
# situation donbas reached critical acute stage
# ----------------------------------------
# Event  20 E D
# FP
# indeed affect economy social sphere
# ----------------------------------------
# Event  21 E D
# FP
# believe head delegation holding talk ukraine make statement soon completed
# ----------------------------------------
# Event  22 E E
# TP
# decision made regard ” said putin
# ----------------------------------------
# Event  23 D E
# FN
# not work otherwise
# ----------------------------------------
# Event  24 E E
# TP
# would like emphasise point risk sudden strike country multiply
# ----------------------------------------
# Event  25 E E
# TP
# collapse soviet union led redivision world norm international law developed time – important fundamental norm adopted following wwii largely formalised outcome – came way declared winner cold war
# ----------------------------------------
# Event  26 D D
# TN
# promised come round talk negotiating position
# ----------------------------------------
# Event  27 E E
# TP
# almost 14,000 civilian including child killed time
# ----------------------------------------
# Event  28 E E
# TP
# rather serious disagreement among point
# ----------------------------------------
# Event  29 E E
# TP
# many people russia convinced talked ukraine ’ position actually determined washington london western capital
# ----------------------------------------
# Event  30 E E
# TP
# second regarding situation ukraine issue discussed issue concern u
# ----------------------------------------
# Event  31 E E
# TP
# would like repeat today centre already deployed ochakov
# ----------------------------------------
# Event  32 D E
# FN
# want talk shanghai cooperation organization observer
# ----------------------------------------
# Event  33 E E
# TP
# good afternoon mr president name maria kotova
# ----------------------------------------
# Event  34 E D
# FP
# horror bucha dismissed fabrication levelling residential area mariupol brushed aside either collateral damage blamed ukrainian soldier
# ----------------------------------------
# Event  35 E E
# TP
# moreover call question economic model imposed developing country entire world recent decade
# ----------------------------------------
# Event  36 E D
# FP
# let spell one time
# ----------------------------------------
# Event  37 E E
# TP
# nothing changed stance keep hearing old reference nato ’ notorious “ open door ” policy
# ----------------------------------------
# Event  38 D E
# FN
# looked happening
# ----------------------------------------
# Event  39 D D
# TN
# alliance defensive would defend
# ----------------------------------------
# Event  40 D E
# FN
# reach goal set
# ----------------------------------------
# Event  41 E E
# TP
# spoke right several day ago news conference talk prime minister hungary
# ----------------------------------------
# Event  42 E E
# TP
# going move “ defence line ” “ defensive ” alliance south china sea go hand-in-hand creating aukus quad dragging japan korea half asean country aukus
# ----------------------------------------
# Event  43 E E
# TP
# responded accordingly pointed ready follow path negotiation provided however issue considered package includes russia ’ core proposal contain three key point
# ----------------------------------------
# Event  44 E E
# TP
# believe common future
# ----------------------------------------
# Event  45 E E
# TP
# strengthen sovereignty science technology allocate additional resource support agriculture processing industry infrastructure housing continue developing foreign trade tie tap rapidly growing dynamic international market
# ----------------------------------------
# Event  46 E D
# FP
# considering moscow washington not establish bilateral dialogue realistic five-sided format plan cooperation country not member official club nuclear power posse weapon — convinced attempt force anyone engage dialogue counterproductive since interaction whether bilateral multilateral format imply joint interested work aimed finding mutually acceptable result
# ----------------------------------------
# Event  47 E D
# FP
# president joe biden cast putin 's invasion ukraine fight much broader global battle democracy autocracy
# ----------------------------------------
# Event  48 E E
# TP
# kremenchug steel plant similar situation
# ----------------------------------------
# Event  49 E D
# FP
# conduct exercise learn method urban warfare sabotage provocation
# ----------------------------------------
# Event  50 E D
# FP
# vladimir zelensky changed mind
# ----------------------------------------
# Event  51 E E
# TP
# nato eu attempt walk fine line deterrence – ever-increasing sanction military aid ukraine – de-escalation putin consistently push crisis along
# ----------------------------------------
# Event  52 E E
# TP
# membership organisation not matter
# ----------------------------------------
# Event  53 D D
# TN
# claim grandfather fought front wwii
# ----------------------------------------
# Event  54 E E
# TP
# not exaggeration fact
# ----------------------------------------
# Event  55 E E
# TP
# let ’ go
# ----------------------------------------
# Event  56 E E
# TP
# take look list country invited summit democracy
# ----------------------------------------
# Event  57 E E
# TP
# practice ‘ special status ’ could mean higher readiness survivability russian nuclear command authority along nuclear force
# ----------------------------------------
# Event  58 E E
# TP
# treat even worse people consider citizen
# ----------------------------------------
# Event  59 E E
# TP
# back relationship situation ground hypothetical say eventual peace settlement
# ----------------------------------------
# Event  60 E E
# TP
# would like additionally emphasise following
# ----------------------------------------
# Event  61 D D
# TN
# not much medium outlet tool inculcating western leader need people 's head
# ----------------------------------------
# Event  62 D D
# TN
# chairman nuclear disarmament forefront international agenda
# ----------------------------------------
# Event  63 E D
# FP
# going keep silent reply accordingly
# ----------------------------------------
# Event  64 D E
# FN
# ukraine outperformed western master inventing sanction citizen company television channel medium outlet even member parliament
# ----------------------------------------
# Event  65 E D
# FP
# `` possible entry finland sweden nato require revision approach defense russian territory `` conclusion already made enshrined updated naval doctrine
# ----------------------------------------
# Event  66 E E
# TP
# would like welcome role member military played border difficult period armenia azerbaijan
# ----------------------------------------
# Event  67 E E
# TP
# going maintain volume infrastructure budget loan
# ----------------------------------------
# Event  68 E E
# TP
# moscow
# ----------------------------------------
# Event  69 E E
# TP
# javelin also portable missile system
# ----------------------------------------
# Event  70 E D
# FP
# day see moscow display military might pomp pride pageantry massive military parade center capital watched putin senior kremlin official
# ----------------------------------------
# Event  71 E E
# TP
# saying “ brawn no brain ” applies
# ----------------------------------------
# Event  72 E E
# TP
# last year alone 23,000 troop thousand unit hardware involved
# ----------------------------------------
# Event  73 E E
# TP
# wanted talk many partner asking delivery
# ----------------------------------------
# Event  74 E E
# TP
# even president trump office united state spoke favour reforming wto
# ----------------------------------------
# Event  75 E E
# TP
# comrade officer father grandfather great-grandfathers not fight nazi occupier not defend common motherland allow today ’ neo-nazis seize power ukraine
# ----------------------------------------
# Event  76 E D
# FP
# probably needed keep public west tenterhook continue fanning russophobia russian becomes target aggression
# ----------------------------------------
# Event  77 E D
# FP
# '' resident donetsk lugansk territory region ukraine consider necessary hold referendum joining russian federation express within framework constitutional duty power course consider issue '' said
# ----------------------------------------
# Event  78 E E
# TP
# united state never regarded democracy
# ----------------------------------------
# Event  79 E E
# TP
# actually included certain material – nothing defence industry formally double-purpose never used double purpose – included material sanction list
# ----------------------------------------
# Event  80 E E
# TP
# addition france holding presidency council european union
# ----------------------------------------
# Event  81 E E
# TP
# see strong position not always coincide european western position
# ----------------------------------------
# Event  82 D E
# FN
# know considered ministry defense
# ----------------------------------------
# Event  83 D D
# TN
#
# ----------------------------------------
# Event  84 D E
# FN
# many speaker expressed concern disruption food supply rising global food price fertilizer
# ----------------------------------------
# Event  85 E E
# TP
# not single point consider unachievable proposal sent nato washington
# ----------------------------------------
# Event  86 E E
# TP
# law education ukrainian language state language russian language no place school public space even ordinary shop
# ----------------------------------------
# Event  87 E E
# TP
# source america ’ traditional policy towards russia
# ----------------------------------------
# Event  88 E E
# TP
# effort vain
# ----------------------------------------
# Event  89 E E
# TP
# nuclear attack japan host war ranging vietnam afghanistan
# ----------------------------------------
# Event  90 D D
# TN
# respect contribution npt state party valuable
# ----------------------------------------
# Event  91 E E
# TP
# several even within administration
# ----------------------------------------
# Event  92 D D
# TN
# military doctrine allows defensive use kind weapon response attack said
# ----------------------------------------
# Event  93 D D
# TN
# coerced end story
# ----------------------------------------
# Event  94 E E
# TP
# launching process different situation talking
# ----------------------------------------
# Event  95 E E
# TP
# numerous warning development posed direct threat security russia rejected open cynical arrogance ukraine u nato patron
# ----------------------------------------
# Event  96 E E
# TP
# instead saying see mission supporting president zelensky kiev ’ position talk russia position president ukraine not united state
# ----------------------------------------
# Event  97 E E
# TP
# look sequence event incoming report showdown russia force not avoided
# ----------------------------------------
# Event  98 E E
# TP
# exchange newly independent state hand russia part soviet foreign asset
# ----------------------------------------
# Event  99 E D
# FP
# matvienko refused speculate fate ukraine 's territory went russia 's control noting resident territory decide
# ----------------------------------------
# Event  100 D D
# TN
# russia declare total war may 9 lavrov reply `` military not plan action based date
# ----------------------------------------
# Event  101 E E
# TP
# like knife throat
# ----------------------------------------
# Event  102 E E
# TP
# first company fulfill order placed government authority company partly owned state paid delivered good service soon possible reinvest proceeds business
# ----------------------------------------
# Event  103 E E
# TP
# agreed least put forth action plan regarding
# ----------------------------------------
# Event  104 E E
# TP
# managed escape describe treated soldier azov battalion “ territorial organisation
# ----------------------------------------
# Event  105 E D
# FP
# understand cover way need want remember probably journalist put-up mission still conscience eight year little girl woman older people killed thousand donbas
# ----------------------------------------
# Event  106 E E
# TP
# '' defense ministry already commented possibility using airfield takeoff military plane
# ----------------------------------------
# Event  107 D E
# FN
# important aspect discussion mr putin
# ----------------------------------------
# Event  108 D D
# TN
# izvestia involvement state military nuclear potential
# ----------------------------------------
# Event  109 E E
# TP
# not fulfil obligation respect sovereign equality state
# ----------------------------------------
# Event  110 D E
# FN
# later turned fake sham iraq not chemical weapon
# ----------------------------------------
# Event  111 E D
# FP
# nato refuse enter conflict side kyiv since direct clash alliance moscow could lead nuclear war
# ----------------------------------------
# Event  112 E E
# TP
# entire system international relation sometimes even u ally
# ----------------------------------------
# Event  113 E D
# FP
# initiative remain force
# ----------------------------------------
# Event  114 D D
# TN
#
# ----------------------------------------
# Event  115 E E
# TP
# reason u president joe biden held “ summit democracy ” late 2021
# ----------------------------------------
# Event  116 E E
# TP
# need unipolar world see every reform carried exclusively within unipolar world philosophy
# ----------------------------------------
# Event  117 E D
# FP
# despite effort explain keep getting question no one hears answer
# ----------------------------------------
# Event  118 D D
# TN
# russia 's action ukraine u
# ----------------------------------------
# Event  119 E E
# TP
# imposing sanction logical continuation distillation irresponsible short-sighted policy u eu country ’ government central bank
# ----------------------------------------
# Event  120 E E
# TP
# matter time
# ----------------------------------------
# Event  121 E D
# FP
# “ ca n't even discussed
# ----------------------------------------
# Event  122 E E
# TP
# followed emergence so-called minsk agreement package measure use official name
# ----------------------------------------
# Event  123 D D
# TN
#
# ----------------------------------------
# Event  124 E E
# TP
# “ yes yes influence right
# ----------------------------------------
# Event  125 E E
# TP
# neither russia european want chaos instability people continent sustained heavy economic social loss pandemic want recovery tranquillity
# ----------------------------------------
# Event  126 D E
# FN
# russia long asked certain security guarantee restriction military deployment presence conventional weapon transparency missile defence intermediate- shorter-range missile
# ----------------------------------------
# Event  127 E E
# TP
# time verkhovna rada speaker noting nothing deleted constitution ukraine continue pursue nato membership like
# ----------------------------------------
# Event  128 E E
# TP
# specifically would mean “ considerable ” naval ground air defense force “ increased tension along border iskanders hypersonic weapon nuclear-armed ship
# ----------------------------------------
# Event  129 E E
# TP
# therefore extend consultation based today ’ discussion move forward try launch new mechanism
# ----------------------------------------
# Event  130 E E
# TP
# law already adopted allows foreign troop come ukraine 2022 take part multinational drill
# ----------------------------------------
# Event  131 E E
# TP
# medvedev cast united state empire spilled blood across world citing killing native american u
# ----------------------------------------
# Event  132 E D
# FP
# ’ interfere situation 10,000 km border set thing right according “ rule
# ----------------------------------------
# Event  133 E E
# TP
# almost go far requesting nato send troop protect ukrainian government
# ----------------------------------------
# Event  134 E E
# TP
# already demonstrated work together including within framework five permanent member un security council
# ----------------------------------------
# Event  135 E E
# TP
# no winner find drawn conflict
# ----------------------------------------
# Event  136 E E
# TP
# able address woman russia bit later
# ----------------------------------------
# Event  137 E E
# TP
# repeatedly warned drawing ukraine nato
# ----------------------------------------
# Event  138 E E
# TP
# work practically finished
# ----------------------------------------
# Event  139 E E
# TP
# antonov famous manufacturer not made single commercial aircraft since 2016 yuzhmash factory specialising missile space equipment nearly bankrupt
# ----------------------------------------
# Event  140 E E
# TP
# russian financial company major enterprise small medium-sized business facing unprecedented pressure
# ----------------------------------------
# Event  141 E E
# TP
# ultimately russia also interested bearing mind level cooperation
# ----------------------------------------
# Event  142 E E
# TP
# company unfriendly country supplied u russia belarus product able produce next year
# ----------------------------------------
# Event  143 E E
# TP
# would like ask government consider increase funding infrastructure facility work start year possibility building purchase russian company instance view upgrading public transport
# ----------------------------------------
# Event  144 E E
# TP
# reaction instantaneous said misunderstanding
# ----------------------------------------
# Event  145 E E
# TP
# ” consequently border would “ strengthened ” “ no non-nuclear status baltic would possible
# ----------------------------------------
# Event  146 E E
# TP
# not know history people well enough
# ----------------------------------------
# Event  147 D E
# FN
# said president zelensky pressed time
# ----------------------------------------
# Event  148 E E
# TP
# example people fly london tokyo complex issue
# ----------------------------------------
# Event  149 D D
# TN
# milley accused russian foreign minister sergey lavrov `` nuclear saber-rattling '' interview last month moscow 's top diplomat said `` danger serious real must not underestimate
# ----------------------------------------
# Event  150 D E
# FN
# five leader put signature statement nuclear war must never happen
# ----------------------------------------
# Event  151 E E
# TP
# ” medvedev also alluded risk nuclear apocalypse suggesting “ horseman apocalypse already way hope lord god almighty
# ----------------------------------------
# Event  152 E E
# TP
# also mentioned number matter particular conflict armenia azerbaijan
# ----------------------------------------
# Event  153 E E
# TP
# claim baltic state neighbour feel threatened well
# ----------------------------------------
# Event  154 E E
# TP
# `` taken note japanese prime minister fumio kishida ’ recent anti-russian remark including controversial statement nuclear weapon issue
# ----------------------------------------
# Event  155 E E
# TP
# far know malian leadership no complaint commercial activity company
# ----------------------------------------
# Event  156 E E
# TP
# sergey lavrov thank inviting
# ----------------------------------------
# Event  157 E E
# TP
# 18th century soldier alexander suvorov fought city
# ----------------------------------------
# Event  158 E E
# TP
# question understand correctly russia continue policy far not ready depart demand put forward start special operation
# ----------------------------------------
# Event  159 E E
# TP
# demonstrated serious difference clear u american
# ----------------------------------------
# Event  160 E D
# FP
# deal reached three year ukraine declared independence launched process kyiv surrendered soviet-era nuclear weapon stored ukraine moscow exchange security assurance
# ----------------------------------------
# Event  161 E E
# TP
# also state emergency
# ----------------------------------------
# Event  162 E E
# TP
# russia cut natural gas suddenly two nato country bulgaria poland wednesday believed attempt punish divide west support ukraine
# ----------------------------------------
# Event  163 E E
# TP
# want direct possible hostile geopolitical design lie behind hypocritical talk recent action so-called collective west
# ----------------------------------------
# Event  164 E E
# TP
# fact step designed make life million people worse attribute aggression war economic political informational mean comprehensive blatant nature
# ----------------------------------------
# Event  165 E E
# TP
# aware price hike big blow people ’ income take action increase social payment shortly including benefit pension raise minimum wage minimum subsistence level also wage public-sector worker
# ----------------------------------------
# Event  166 E E
# TP
# regard first part question want reiterate said would really like hear time convey message reader viewer internet user
# ----------------------------------------
# Event  167 D E
# FN
# listen carefully
# ----------------------------------------
# Event  168 E E
# TP
# not mean nation not enjoy right self-determination enshrined article 1 un charter
# ----------------------------------------
# Event  169 E E
# TP
# clearly new reality make deep structural change economy not pretend easy not lead temporary increase inflation unemployment
# ----------------------------------------
# Event  170 E D
# FP
# france succeeds bringing agreement time make u happy long agreement based principle approved osce enshrined international relation
# ----------------------------------------
# Event  171 D D
# TN
# remember well
# ----------------------------------------
# Event  172 E D
# FP
# vision country essence nuclear deterrence definition military risk threat neutralized nuclear deterrence specified basic principle state policy russian federation nuclear deterrence
# ----------------------------------------
# Event  173 D E
# FN
# question interesting important conversation minister foreign affair russian federation
# ----------------------------------------
# Event  174 E D
# FP
# continue work towards resolving issue
# ----------------------------------------
# Event  175 E E
# TP
# owing courage became part russia
# ----------------------------------------
# Event  176 E E
# TP
# next notably article 17 constitution ukraine stipulates deploying foreign military base territory illegal
# ----------------------------------------
# Event  177 E E
# TP
# yes course back so-called fifth column national traitor – make money country live “ live ” not geographical sense word mind servile mentality
# ----------------------------------------
# Event  178 E E
# TP
# nation even russian people always able distinguish true patriot scum traitor simply spit like insect mouth spit onto pavement
# ----------------------------------------
# Event  179 E E
# TP
# basically already replied say
# ----------------------------------------
# Event  180 E E
# TP
# lukashenko 110 percent
# ----------------------------------------
# Event  181 E E
# TP
# ” according ryabkov western country “ trying accuse u allegedly playing kind rhetorical game
# ----------------------------------------
# Event  182 E E
# TP
# “ third attack critical infrastructure paralysed nuclear deterrent force
# ----------------------------------------
# Event  183 E E
# TP
# change readiness status could difficult spot ass
# ----------------------------------------
# Event  184 E E
# TP
# honest proposal refusing ever since
# ----------------------------------------
# Event  185 E E
# TP
# meanwhile radical became increasingly brazen action made demand every year
# ----------------------------------------
# Event  186 E D
# FP
# past week president vladimir putin repeatedly explained detail view
# ----------------------------------------
# Event  187 E E
# TP
# no channel
# ----------------------------------------
# Event  188 D E
# FN
# russia ’ 2020 nuclear doctrine state role russia ’ nuclear force not deterrence also guarantee ‘ protection sovereignty territorial integrity state … event outbreak military conflict – preclusion escalation military action cessation condition acceptable russian federation ally ’
# ----------------------------------------
# Event  189 E E
# TP
# vladimir putin look developed entire system support family especially family child
# ----------------------------------------
# Event  190 E D
# FP
# example top foreign ministry official talk profusely subject
# ----------------------------------------
# Event  191 E E
# TP
# noted ukraine actually never stable tradition real statehood
# ----------------------------------------
# Event  192 E E
# TP
# later speech putin also emphasized russia “ one powerful nuclear state ” “ certain advantage several cutting-edge weapon
# ----------------------------------------
# Event  193 E D
# FP
# justified feb
# ----------------------------------------
# Event  194 E E
# TP
# first protect people live donbas course
# ----------------------------------------
# Event  195 E D
# FP
# western colleague not ready playing absolute good grossly abusing diplomatic method forcing small medium-sized country carry order
# ----------------------------------------
# Event  196 E E
# TP
# naturally could not support since threatened nationalist neo-nazis
# ----------------------------------------
# Event  197 E E
# TP
# issued lot verbal assurance turned empty phrase
# ----------------------------------------
# Event  198 E D
# FP
# vladimir putin put nuclear force high alert late february soon invasion widely perceived warning
# ----------------------------------------
# Event  199 D E
# FN
# ridiculous
# ----------------------------------------
# Event  200 E E
# TP
# 2021 black sea shipyard nikolayev went business
# ----------------------------------------
# Event  201 E D
# FP
# provided necessary explanation repeatedly
# ----------------------------------------
# Event  202 E E
# TP
# would ask talk detail defense issue important u critically important connection happening west well security issue
# ----------------------------------------
# Event  203 E E
# TP
# know fact
# ----------------------------------------
# Event  204 E E
# TP
# overcome difficulty well
# ----------------------------------------
# Event  205 D E
# FN
# mr
# ----------------------------------------
# Event  206 E E
# TP
# ” let say right away – not accept behaviour never accept
# ----------------------------------------
# Event  207 D D
# TN
# nevertheless talk must take place
# ----------------------------------------
# Event  208 E E
# TP
# “ russia deliberating bragging destroy nuclear weapon not certain country entire planet ” zelenskiy said
# ----------------------------------------
# Event  209 E E
# TP
# necessary underscore
# ----------------------------------------
# Event  210 E E
# TP
# hope mr president intends – rate said earlier today – discus discussed today regard european security stability guarantee meeting kiev leader tomorrow
# ----------------------------------------
# Event  211 D E
# FN
# support killed russian jew pole war hail hero
# ----------------------------------------
# Event  212 E E
# TP
# know missile strike centre donetsk march 14
# ----------------------------------------
# Event  213 E D
# FP
# see demilitarisation carried way meaning destruction infrastructure weapon posing threat u
# ----------------------------------------
# Event  214 D E
# FN
# want seized continue hold power kiev immediately stop hostility
# ----------------------------------------
# Event  215 E D
# FP
# russia ’ constitution allows martial law introduced country attack external force concern russia could prepare “ false flag ” attack justify all-out war martial law
# ----------------------------------------
# Event  216 E E
# TP
# connected defending russia taken ukraine hostage trying use country people
# ----------------------------------------
# Event  217 E E
# TP
# must domestic flight
# ----------------------------------------
# Event  218 D D
# TN
# not feeling political loneliness
# ----------------------------------------
# Event  219 E E
# TP
# well-known steinmeier formula – well-known specialist rate – approved certain amendment minsk accord made definite concession yet included ukrainian legislation
# ----------------------------------------
# Event  220 D D
# TN
# practical scenario use involving non-nuclear-weapon state exercised within nato
# ----------------------------------------
# Event  221 E D
# FP
# crimea would remained ukrainian
# ----------------------------------------
# Event  222 E E
# TP
# trying convince u nato peace-loving purely defensive alliance pose no threat russia
# ----------------------------------------
# Event  223 E D
# FP
# another telephone conversation underway moment
# ----------------------------------------
# Event  224 E D
# FP
# n
# ----------------------------------------
# Event  225 E E
# TP
# need talk detail related logistics
# ----------------------------------------
# Event  226 E E
# TP
# agreed raised issue made decision within next month transfer belarus iskander-m tactical missile system know use ballistic cruise missile conventional nuclear version
# ----------------------------------------
# Event  227 D E
# FN
# speculation kind
# ----------------------------------------
# Event  228 E E
# TP
# develop transport infrastructure manufacture aircraft
# ----------------------------------------
# Event  229 E E
# TP
# getting position coveted people immediately betrayed voter going back election promise instead steering policy prompted radical sometimes even persecuting former ally – public organisation supported bilingualism cooperation russia
# ----------------------------------------
# Event  230 D E
# FN
# elite not thinking improve life citizen western country
# ----------------------------------------
# Event  231 E E
# TP
# worry adopting legislation discriminates russian speaker denied right recognised core nation properly speaking homeland right speak native language quite odd no way reflected approach adopted european country
# ----------------------------------------
# Event  232 D E
# FN
# violated territorial integrity
# ----------------------------------------
# Event  233 E E
# TP
# course russia european union need settle conflict move forward relation
# ----------------------------------------
# Event  234 E E
# TP
# knew would like second sight happened
# ----------------------------------------
# Event  235 E D
# FP
# russia seek make practical contribution freeing world threat posed wmd including nuclear weapon
# ----------------------------------------
# Event  236 E E
# TP
# ended making tried strip u – invented innovative material even better foreign-made one
# ----------------------------------------
# Event  237 E E
# TP
# ta no official information matter
# ----------------------------------------
# Event  238 E D
# FP
# talked complex technically capable carrying various type weapon '' peskov said answering question whether issue transferring nuclear missile minsk worth
# ----------------------------------------
# Event  239 E E
# TP
# attempting represent situation azovstal created russia
# ----------------------------------------
# Event  240 D E
# FN
# '' two week hearing television screen nuclear silo opened '' russian newspaper editor nobel peace prize laureate dmitry muratov said tuesday
# ----------------------------------------
# Event  241 E E
# TP
# least three off-ramps available
# ----------------------------------------
# Event  242 E E
# TP
# would like say first time start operation donbas kiev authority offered opportunity avoid hostility via different channel simply withdraw troop donbas alternative bloodshed
# ----------------------------------------
# Event  243 E D
# FP
# however best answer came fellow citizen french journalist visited donbas described shelling school death two woman two teacher worked school shamed western leader refuse see
# ----------------------------------------
# Event  244 E D
# FP
# feel russia fueling hysteria include top u
# ----------------------------------------
# Event  245 E D
# FP
# side avangard missile system hypersonic boost-glide vehicle
# ----------------------------------------
# Event  246 E E
# TP
# emmanuel macron get back question think first france ’ responsibility strongest possible relationship russia
# ----------------------------------------
# Event  247 D D
# TN
# goal not regime change ukraine american specialty usually deal world want ensure safety people
# ----------------------------------------
# Event  248 E E
# TP
# movement russian force kiev ukrainian city not connected desire occupy country
# ----------------------------------------
# Event  249 E E
# TP
# wave violence swept ukrainian city including series high-profile unpunished murder
# ----------------------------------------
# Event  250 D D
# TN
# first time putin 's minister grant interview european tv attack `` western medium always misrepresent say ''
# ----------------------------------------
# Event  251 E D
# FP
# thank mr
# ----------------------------------------
# Event  252 E E
# TP
# circumstance take bold immediate action
# ----------------------------------------
# Event  253 D D
# TN
# `` arm control experience cooperation west field arm control show policy `` not imply fulfillment treaty obligation traditional sense '' fact must taken account
# ----------------------------------------
# Event  254 E D
# FP
# ultrasonic weapon developed u missile shield aimed russia china weapon developed
# ----------------------------------------
# Event  255 D D
# TN
# ’ occurred anyone start uprising crimea putschists
# ----------------------------------------
# Event  256 E E
# TP
# moreover say something never said publicly say first time
# ----------------------------------------
# Event  257 E D
# FP
# started talking western capital issuing demand
# ----------------------------------------
# Event  258 E E
# TP
# russia ’ northern fleet said statement several nuclear submarine involved exercise designed “ train maneuvering stormy condition
# ----------------------------------------
# Event  259 E E
# TP
# weapon legitimate target russian armed force special operation
# ----------------------------------------
# Event  260 E E
# TP
# extremely important people business
# ----------------------------------------
# Event  261 E E
# TP
# 3
# ----------------------------------------
# Event  262 E D
# FP
# russia ’ best interest well
# ----------------------------------------
# Event  263 E D
# FP
# mind work one way – punish russia much possible
# ----------------------------------------
# Event  264 E D
# FP
# russian president vladimir putin meeting belarusian counterpart alexander lukashenko not talk transfer missile nuclear weapon minsk complex technically capable carrying various type weapon press secretary russian leader dmitry peskov told ria novosti
# ----------------------------------------
# Event  265 E E
# TP
# would like emphasise point draw attention troop acted within people 's republic helped liberate territory would not final solution would not led peace would not ultimately removed threat – country time russia
# ----------------------------------------
# Event  266 D E
# FN
# clearly understand given scenario level military threat russia increase dramatically several time
# ----------------------------------------
# Event  267 E E
# TP
# consider intermediary convey message european mr macron could also answer question pmc wagner ’ presence whether russia involved way vladimir putin already covered issue
# ----------------------------------------
# Event  268 E E
# TP
# first really main one necessary appease nationalist satisfy ceaselessly growing nationalist ambition outskirt former empire point transferring newly often arbitrarily formed administrative unit – union republic – vast territory nothing let repeat territory transferred along population historically russia
# ----------------------------------------
# Event  269 E E
# TP
# otherwise nato de facto entered proxy war russia arming proxy
# ----------------------------------------
# Event  270 E D
# FP
# country right choose alliance
# ----------------------------------------
# Event  271 E E
# TP
# therefore searching common ground political solution not mean agree everything
# ----------------------------------------
# Event  272 D D
# TN
# may come attention primarily europe united state trying shut russian medium source information development ukraine ongoing special military operation way ukrainian army ukrainian neo-nazi battalion treating civilian
# ----------------------------------------
# Event  273 D E
# FN
# fourth case act aggression committed russia ally jeopardised existence country even without use nuclear weapon use conventional weapon
# ----------------------------------------
# Event  274 E E
# TP
# sensitive issue constitutional reform election discussion developed near future
# ----------------------------------------
# Event  275 E E
# TP
# according expert assessment confirmed simple calculation energy price subsidised loan russia provided ukraine along economic trade preference overall benefit ukrainian budget period 1991 2013 amounted 250 billion
# ----------------------------------------
# Event  276 E E
# TP
# also direct assistance foreign state
# ----------------------------------------
# Event  277 E E
# TP
# many country immediate future may begin – sure happen – convert paper digital asset real reserve raw material land food gold real asset result shortage market
# ----------------------------------------
# Event  278 E D
# FP
# gone wrong ’ think ’ familiar plan kept secret
# ----------------------------------------
# Event  279 E E
# TP
# happening also important
# ----------------------------------------
# Event  280 D D
# TN
# question retranslated despite nuclear fear russia united state managed maintain stability decade
# ----------------------------------------
# Event  281 E E
# TP
# practice showed immediately impossible preserve govern vast complex territory amorphous principle amounted confederation
# ----------------------------------------
# Event  282 E E
# TP
# could simply way answer question part help republic donbas right line contact frontline say simply reinforce army
# ----------------------------------------
# Event  283 E E
# TP
# second state alert
# ----------------------------------------
# Event  284 E E
# TP
# medvedev explained necessary aspect documented doctrine
# ----------------------------------------
# Event  285 E E
# TP
# impossible ukraine
# ----------------------------------------
# Event  286 E E
# TP
# kept advancing not going change anything
# ----------------------------------------
# Event  287 E E
# TP
# brings situation donbas
# ----------------------------------------
# Event  288 E E
# TP
# not joking told know come time granting political asylum humanitarian reason
# ----------------------------------------
# Event  289 E E
# TP
# nevertheless denouement crisis require face-saving option moscow
# ----------------------------------------
# Event  290 D D
# TN
# mortal
# ----------------------------------------
# Event  291 E E
# TP
# look people donbas not stray dog
# ----------------------------------------
# Event  292 E E
# TP
# martial law
# ----------------------------------------
# Event  293 E E
# TP
# obligation not transfer helicopter third party set forth end-use certificate first signed 2013 helicopter package hillary clinton secretary state john kerry
# ----------------------------------------
# Event  294 E E
# TP
# seems u generally speaking know fact common knowledge
# ----------------------------------------
# Event  295 E E
# TP
# using so-called jihad mobile – stuff car explosive drive towards troop
# ----------------------------------------
# Event  296 E E
# TP
# not trying put blame anyone
# ----------------------------------------
# Event  297 E D
# FP
# touched many issue
# ----------------------------------------
# Event  298 E D
# FP
# playing everyone ’ nerve yet another display western cynicism '' ryabkov said
# ----------------------------------------
# Event  299 E E
# TP
# overall agreed continue mutually beneficial cooperation politics trade economy well sphere including cultural humanitarian tie
# ----------------------------------------
# Event  300 D E
# FN
# second putin could claim victory seize donetsk luhansk exaggerate military achievement audience back home leave rest ukraine
# ----------------------------------------
# Event  301 D E
# FN
# `` right use country ’ strategic nuclear force response attack involving weapon mass destruction u ally response threat country ’ existence word danger threatens existence state
# ----------------------------------------
# Event  302 E E
# TP
# addition prime minister mikhail mishustin presidential plenipotentiary envoy urals federal district vladimir yakushev minister economic development maxim reshetnikov minister agriculture dmitry patrushev head chechnya ramzan kadyrov also delivered remark
# ----------------------------------------
# Event  303 E E
# TP
# already made decision – know – introduce april 1 payment child aged 8 16 low-income family
# ----------------------------------------
# Event  304 E E
# TP
# kiev not preparing war aggression russia – conducting
# ----------------------------------------
# Event  305 E E
# TP
# following fact also revealing since 2020 60,000 doctor health worker left country amid pandemic
# ----------------------------------------
# Event  306 D E
# FN
# personally said number time
# ----------------------------------------
# Event  307 E E
# TP
# ukraine nuclear technology created back soviet time delivery vehicle weapon including aircraft well soviet-designed tochka-u precision tactical missile range 100 kilometre
# ----------------------------------------
# Event  308 E E
# TP
# trump administration refused proceed formula
# ----------------------------------------
# Event  309 E E
# TP
# nuclear weapon powerful reminder russia ’ military strength
# ----------------------------------------
# Event  310 E E
# TP
# “ right ” respond “ not happen tomorrow happen day tomorrow
# ----------------------------------------
# Event  311 E E
# TP
# expect complete negotiation agreement must keep mind istanbul meeting took place certain backdrop ground
# ----------------------------------------
# Event  312 E E
# TP
# question regard case country sign document bucharest 2008 open door nato country know tried talk avoiding certain action 30 year
# ----------------------------------------
# Event  313 E D
# FP
# march putin signed decree ordering 134,500 new conscript army raising eyebrow could destined fight ukraine putin insisted would not
# ----------------------------------------
# Event  314 D D
# TN
# `` massacre civilian bucha lavrov reply `` march 30 russian soldier left bucha
# ----------------------------------------
# Event  315 D D
# TN
# 26 october 2020 president russian federation vladimir putin statement additional step de-escalate situation europe context termination treaty non-proliferation nuclear weapon reiterating initiative reciprocal moratorium invited party concerned consider specific option reciprocal verification measure address existing concern
# ----------------------------------------
# Event  316 E D
# FP
# mayor bucha declared victory saying bucha returned normal life three day began show dead
# ----------------------------------------
# Event  317 E D
# FP
# cia extensive presence time
# ----------------------------------------
# Event  318 E E
# TP
# speaking directly today not explain happening also inform decision made well potential step
# (202, 33, 55, 29)

# %%
def calculate_f1_score(tp, tn, fp, fn):
    if tp+fp == 0:
      precision = 0.0
    else:
      precision = tp / (tp + fp)
    
    if tp+fn == 0:
      recall = 0.0
    else:
      recall = tp / (tp + fn)
    if precision + recall == 0:
      f1_score = 0.0
    else:
      f1_score = 2 * (precision * recall) / (precision + recall)
    return f1_score

def calculate_accuracy(tp, tn, fp, fn):
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    return accuracy

print("F1: ", calculate_f1_score(tp, tn, fp, fn))
print("Accuracy: ", calculate_accuracy(tp, tn, fp, fn))
# Out:
# F1:  0.8278688524590164
# Accuracy:  0.7366771159874608

# %% [markdown]
# #Top words associated with each class

# %%
import pandas as pd
import re

df = nuclear_threat
# Assuming 'df' is your dataframe and 'text_column' is the column containing the text data
text_data = ' '.join(df['text'].astype(str).tolist())

# Tokenize the text into individual words
tokens = nltk.word_tokenize(text_data)

# Generate ngrams from the tokens
bigrams = nltk.ngrams(tokens, 5)

# Get unique bigrams using a set
unique_bigrams = set(bigrams)

# Convert the set back to a list
unique_bigrams_list = list(unique_bigrams)
unique_bigrams_list = [" ".join(b) for b in unique_bigrams]

texts = unique_bigrams_list
docs = [nlp.tokenizer(text) for text in texts]

# Use textcat to get the scores for each doc
if assume:
  textcat = nlp.get_pipe('textcat')
else:
  textcat = nlp.get_pipe('textcat_multilabel')
scores = textcat.predict(docs)

dictionary = {k: v[0] for k, v in zip(texts, scores)} #v[0] -- escalation; v[1] -- de-escalation

sorted_dict = dict(sorted(dictionary.items(), key=lambda x: x[1],reverse=True))

top_k = 50
i = 0
for key, value in sorted_dict.items():
    print(key, value)
    i+=1
    if i == top_k:
      break
# Out:
# regime outwardly looked wonderful attractive 1.0
# also touched upon topical international 1.0
# also find new joint solution 1.0
# u guarantee not happen also 1.0
# also generally accepted norm morality 1.0
# statement unit involved also practiced 1.0
# must also find new joint 1.0
# west would provided endless support 1.0
# account russian company individual also 1.0
# immediate responsibility especially training also 1.0
# mind russia belarus largest supplier 1.0
# people russia said wednesday force 1.0
# minsk agreement signed approved un 1.0
# economy global trade whole suffered 1.0
# inherited not soviet era also 1.0
# everyone russia everyone blaming russia 1.0
# principle committed risk quite high 1.0
# according statement unit involved also 1.0
# gorbachev reagan said 1987 accept 1.0
# lost industrial technological potential – 0.9999999
# whelan brittney griner realistic proposal 0.9999999
# done blatantly stated united state 0.9999999
# important people business people aware 0.9999999
# everyone ’ mantra third world 0.9999999
# issue touched upon diverse issue 0.9999999
# contract advance payment must amount 0.9999999
# france ’ partner within normandy 0.9999999
# point said nevertheless tried find 0.9999999
# saying key matter must settled 0.9999999
# idea drastically different done istanbul 0.9999999
# carrying responsibility admirably obviously attempt 0.9999999
# dollar oligarch stolen ukrainian holding 0.9999999
# eu initiative position score also 0.9999999
# not hold planned drill exercise 0.9999999
# staff fully justified fellow – 0.9999999
# day similar decision must also 0.9999999
# deputy come go deep aggressive 0.9999999
# done istanbul huge lenin-style step 0.9999999
# whole suffered major blow trust 0.9999999
# carried operation crimea anywhere else 0.9999999
# founding act signed principled proposal 0.9999999
# drastically different done istanbul huge 0.9999999
# ussr recognised new independent state 0.9999999
# defeat came tremendous cost attempt 0.9999999
# order beijing absorb message ’ 0.9999999
# people aware country managed realise 0.9999999
# also respect sovereignty independence state 0.9999999
# unfortunately not located territory kyiv 0.99999976
# president assessment prospect settlement southeastern 0.99999976
# global trade whole suffered major 0.99999976
