# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Hyperparameters 

threat_path = '.../nuclear_threat.csv'

by_column = "text" #choose a column on which the data will be trained: "text", "text-medium", "text-short"
side = 'w' # w -- West, r -- Russia
assume = ('W', 'E') #must be a tuple of (label_to_change, suggested_label_instead). "W" -- Warning, "E" -- Escalatory, "D" -- De-escalatory

to_expand = True #if True -- trained sentence-wise
n_epochs = 8 #no. of epochs that model will be trained on
test_on = by_column

# %% [markdown]
# #Expand Data

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_text(text):
    # Tokenize the text into words
    tokens = word_tokenize(text.lower())
    
    # Remove punctuation
    tokens = [token for token in tokens if token not in string.punctuation]
    
    # Remove stop words
    stop_words = set(stopwords.words('english')).difference({"not", "no"})
    tokens = [token for token in tokens if token not in stop_words]
    
    # Lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    return " ".join(tokens)

# Example usage
text = "Hello, how not are you doing today? I hope everything is going well!"
preprocessed_text = preprocess_text(text)
print(preprocessed_text)
# Out:
# hello not today hope everything going well
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def expand(data, type, side=None, binary_assumption=None, sent_level = to_expand):
  expanded_data = pd.DataFrame(columns=data.columns)

  if sent_level:
    #if sent_level is True, then we will split the text in a given cell
    #into sentences and split one row into multiple rows of corresponding values
    
    for index, row in data.iterrows():
        text = row[type]
        label = row["label"]
        
        # Split the text into sentences
        sentences = text.split(".")
        
        # Create a new row for each sentence
        for sentence in sentences:
            if sentence.strip() != "":
                sentence = preprocess_text(sentence)
                expanded_data = pd.concat([expanded_data, pd.DataFrame({**row, type: sentence.strip()}, index=[0])], ignore_index=True)
  else:
    expanded_data = data

  if side:
    expanded_data = expanded_data[expanded_data['side'] == side]
  if binary_assumption:
    prev_label, new_label = binary_assumption[0], binary_assumption[1]
    expanded_data.loc[expanded_data['label'] == prev_label, 'label'] = new_label
  return expanded_data

# %% [markdown]
# # Text Classification with SpaCy

# %%
from tkinter.constants import N
import pandas as pd

nuclear_threat = pd.read_csv(threat_path)
nuclear_threat = expand(nuclear_threat, by_column, side, binary_assumption=assume, sent_level=to_expand)
len(nuclear_threat)
# Out:
# 3482

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Splitting the DataFrame into train and test sets
nuclear_threat_train, nuclear_threat_test = train_test_split(nuclear_threat, test_size=0.1, random_state=40)

print("Train DataFrame:")
print(len(nuclear_threat_train))
print("\nTest DataFrame:")
print(len(nuclear_threat_test))
nuclear_threat_test
# Out:
# Train DataFrame:
# 3133
#
# Test DataFrame:
# 349
#             date                                               text  \
# 6696  2022-08-16  mil/about/fact-sheets/article/454593/air-force...
# 2854  2022-03-11                                   thing ’ veto pen
# 4501  2022-04-19                                   not exaggeration
# 3049  2022-03-16  combined massive support ukrainian armed force...
# 3005  2022-03-16  marilu lucrezio rai tv comment italy 's role c...
# ...          ...                                                ...
# 6460  2022-07-20  ” u military ’ responsibility “ provide presid...
# 3953  2022-04-01  even lower end hypersonic range – 3,800 mile p...
# 3607  2022-03-23                        president no ’ not thanking
# 5390  2022-04-27
# 3084  2022-03-16                                    get united nato
#
#                                             text-medium  \
# 6696  The US military apparently returned to its nor...
# 2854  On the same day, Biden also stressed that whil...
# 4501  On April 19, Pentagon spokesperson Kirby furth...
# 3049  In the press conference following the NATO def...
# 3005  In the press conference following the NATO def...
# ...                                                 ...
# 6460  Against this background, US military officials...
# 3953  Nevertheless, the US military took no chances ...
# 3607  Echoing earlier statements from US officials, ...
# 5390  In an April 27 briefing, Pentagon spokesperson...
# 3084  In the press conference following the NATO def...
#
#                                              text-short side label  \
# 6696        US test launch of the Minuteman III ICBM.\n    w     E
# 2854   Biden: NATO will be defended, but a direct co...    w     D
# 4501   Kirby: Washington is monitoring Russian rheto...    w     D
# 3049  NATO decides not to send peacekeeping troops t...    w     D
# 3005  NATO decides not to send peacekeeping troops t...    w     D
# ...                                                 ...  ...   ...
# 6460   Brown: If Putin uses nuclear weapons in Ukrai...    w     D
# 3953             Pentagon cancels Minuteman III test.\n    w     D
# 3607  Stoltenberg: „Any use of nuclear weapons will ...    w     E
# 5390  Kirby: United States do not want “to see Russi...    w     E
# 3084  NATO decides not to send peacekeeping troops t...    w     D
#
#                         comment
# 6696                        NaN
# 2854                        NaN
# 4501                        NaN
# 3049                        NaN
# 3005                        NaN
# ...                         ...
# 6460  video; copied from medium
# 3953                        NaN
# 3607                        NaN
# 5390                        NaN
# 3084                        NaN
#
# [349 rows x 7 columns]

# %% [markdown]
# # Building a Bag of Words model

# %%
import spacy
# Create an empty model
nlp = spacy.blank("en")

# %%
if assume:
  #binary classification
  # Add the TextCategorizer to the empty model
  textcat = nlp.add_pipe("textcat")
  # Add labels to text classifier
  textcat.add_label("E")
  textcat.add_label("D")
else:
  #multiple labels
  textcat = nlp.add_pipe("textcat_multilabel")
  textcat.add_label("E")
  textcat.add_label("D")
  textcat.add_label("W")

# %% [markdown]
# # Training a Text Categorizer Model

# %%
train_texts = nuclear_threat_train[by_column].values
if assume:
  train_labels = [{'cats': {'E': label == 'E',
                            'D': label == 'D'}} 
                  for label in nuclear_threat_train['label']]
else:
  train_labels = [{'cats': {'E': label == 'E',
                          'D': label == 'D', 'W':label == 'W'}} 
                for label in nuclear_threat_train['label']]

# %% [markdown]
# Then we combine the texts and labels into a single list.

# %%
train_data = list(zip(train_texts, train_labels))
train_data[:10]
# Out:
# [("'re seeing today roughly consistent saw yesterday",
#   {'cats': {'E': False, 'D': True}}),
#  ('“ understandable concern ” polish proposal',
#   {'cats': {'E': False, 'D': True}}),
#  ("'s lot plate", {'cats': {'E': False, 'D': True}}),
#  ('think forgiven wanting make sure get stuff use quickly effectively field',
#   {'cats': {'E': False, 'D': True}}),
#  ('condemn sham “ trial ” resulting application death sentence member ukrainian armed force',
#   {'cats': {'E': True, 'D': False}}),
#  ("think 's also important add n't lot rhetoric following initial salvo early day",
#   {'cats': {'E': False, 'D': True}}),
#  ("clearly n't appear interested 're still fighting donbas south",
#   {'cats': {'E': True, 'D': False}}),
#  ('welcome effort increase cooperation investigation taking place ukraine intensify police judicial cooperation ukraine well relevant organisation',
#   {'cats': {'E': True, 'D': False}}),
#  ('russian influence start working neighbour country moldova georgia also impact western balkan',
#   {'cats': {'E': True, 'D': False}}),
#  ('josh bloomberg', {'cats': {'E': True, 'D': False}})]

# %%
from spacy.util import minibatch
from spacy.training.example import Example

spacy.util.fix_random_seed(1)
optimizer = nlp.begin_training()

# Create the batch generator with batch size = 8
batches = minibatch(train_data, size=8)
# Iterate through minibatches
for batch in batches:
    # Each batch is a list of (text, label) 
    for text, labels in batch:
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, labels)
        nlp.update([example], sgd=optimizer)

# %% [markdown]
# This is just one training loop (or epoch) through the data. The model will typically need multiple epochs. Use another loop for more epochs, and optionally re-shuffle the training data at the begining of each loop.

# %%
import random

random.seed(1)
spacy.util.fix_random_seed(1)
optimizer = nlp.begin_training()

losses = {}
for epoch in range(n_epochs):
    random.shuffle(train_data)
    # Create the batch generator with batch size = 8
    batches = minibatch(train_data, size=8)
    # Iterate through minibatches
    for batch in batches:
        for text, labels in batch:
            doc = nlp.make_doc(text)
            example = Example.from_dict(doc, labels)
            nlp.update([example], sgd=optimizer, losses=losses)
    print(losses)
# Out:
# {'textcat': 852.7124040069709}
# {'textcat': 1488.756337341253}
# {'textcat': 1921.5418028594784}
# {'textcat': 2206.393144192325}
# {'textcat': 2411.3974209487005}
# {'textcat': 2578.143257811827}
# {'textcat': 2716.080651251046}
# {'textcat': 2831.941919103612}

# %% [markdown]
# # Making Predictions

# %%
texts = nuclear_threat_test[test_on]
docs = [nlp.tokenizer(text) for text in texts]

# Use textcat to get the scores for each doc
if assume:
  textcat = nlp.get_pipe('textcat')
else:
  textcat = nlp.get_pipe('textcat_multilabel')
scores = textcat.predict(docs)

# %% [markdown]
# The scores are used to predict a single class or label by choosing the label with the highest probability. You get the index of the highest probability with `scores.argmax`, then use the index to get the label string from `textcat.labels`.

# %%
# From the scores, find the label with the highest score/probability
predicted_labels = scores.argmax(axis=1)
predicted_labels = [textcat.labels[label] for label in predicted_labels]

# %% [markdown]
# Examples

# %%
# texts = ["russia has a right for defensive nuclear alert"]
# docs = [nlp.tokenizer(text) for text in texts]
    
# # Use textcat to get the scores for each doc
# textcat = nlp.get_pipe('textcat')
# scores = textcat.predict(docs)
# # From the scores, find the label with the highest score/probability
# predicted_labels = scores.argmax(axis=1)
# predicted_labels = [textcat.labels[label] for label in predicted_labels]
# predicted_labels

# %% [markdown]
# #Evaluation. Confusion matrix

# %%
labels_test = list(nuclear_threat_test['label'])
len(labels_test)
# Out:
# 349

# %%
tp = 0
tn = 0
fp = 0
fn = 0

for i in range(len(labels_test)):
  print(40*"-")
  print("Event ", i, predicted_labels[i], labels_test[i])
  if predicted_labels[i] == "E" and labels_test[i] == "E":
    tp += 1
    print("TP")
  if predicted_labels[i] != "E" and labels_test[i] != "E":
    tn += 1
    print("TN")
  if predicted_labels[i] == "E" and labels_test[i] != "E":
    fp += 1
    print("FP")
  if predicted_labels[i] != "E" and labels_test[i] == "E":
    fn += 1
    print("FN")
  print(docs[i])
tp, tn, fp, fn
# Out:
# ----------------------------------------
# Event  0 D E
# FN
# mil/about/fact-sheets/article/454593/air-force-global-strike-command-air-forces-strategic-air/
# ----------------------------------------
# Event  1 D D
# TN
# thing ’ veto pen
# ----------------------------------------
# Event  2 D D
# TN
# not exaggeration
# ----------------------------------------
# Event  3 D D
# TN
# combined massive support ukrainian armed force receiving actually received nato allied country many year forced president putin change stance realise quick victory blitzkrieg taking control kiev within day actually failed
# ----------------------------------------
# Event  4 D D
# TN
# marilu lucrezio rai tv comment italy 's role current crisis happy birthday today nato secretary general thank
# ----------------------------------------
# Event  5 D D
# TN
# thought could divide democrat republican home
# ----------------------------------------
# Event  6 E E
# TP
# supposed hour ago european union meeting — speak
# ----------------------------------------
# Event  7 D D
# TN
# multiple shipment going
# ----------------------------------------
# Event  8 E D
# FP
# time tension united state russia must bear mind risk miscalculation take step reduce risk press secretary said
# ----------------------------------------
# Event  9 E D
# FP
# one lesson learn going ukraine today need support country risk
# ----------------------------------------
# Event  10 D D
# TN
# lead-up invasion since information pentagon provided really tracked well source u
# ----------------------------------------
# Event  11 E E
# TP
# 5 billion
# ----------------------------------------
# Event  12 E D
# FP
# austin already postponed test early march avoid action could misconstrued russia sensitive time
# ----------------------------------------
# Event  13 D D
# TN
# mean artillery -- -- radar system coastal defense unmanned system 're talking
# ----------------------------------------
# Event  14 D E
# FN
# mean 'm not going get ahead
# ----------------------------------------
# Event  15 D D
# TN
# look russian want -- 'm not inside strategist head moscow
# ----------------------------------------
# Event  16 E E
# TP
# best every case make sure claim treated fairly appropriately judiciously
# ----------------------------------------
# Event  17 D D
# TN
# rachel scott abc news congresional correspondent oh definitely george
# ----------------------------------------
# Event  18 E E
# TP
# accordance agreement president european commission ursula von der leyen already anticipated yesterday working g7 member taking package measure council approved question scope – full support measure really effectively crippling russian financial market
# ----------------------------------------
# Event  19 D D
# TN
# trying get ukrainian also asking thing beyond mean 'm talking tank aircraft
# ----------------------------------------
# Event  20 D D
# TN
# represents global scale n't know heather n't data food 's food market
# ----------------------------------------
# Event  21 E D
# FP
# off-year election view may important off-year election modern history
# ----------------------------------------
# Event  22 E E
# TP
# 're working
# ----------------------------------------
# Event  23 D D
# TN
# useucom poland 's military force united aligned operation activity
# ----------------------------------------
# Event  24 D D
# TN
# est president sorry keep waiting
# ----------------------------------------
# Event  25 E E
# TP
# instead saying — ukrainian equipped capability resist russian force ’ got say — tell people united state nato engaged — taking russian troop tank et cetera
# ----------------------------------------
# Event  26 E E
# TP
# weapon flowing ukraine speak
# ----------------------------------------
# Event  27 D D
# TN
# n't talk route
# ----------------------------------------
# Event  28 D D
# TN
# nato secretary general meeting nato foreign minister today
# ----------------------------------------
# Event  29 D E
# FN
# cross-talk reporter
# ----------------------------------------
# Event  30 E D
# FP
# `` remain confident strategic posture '' kirby said
# ----------------------------------------
# Event  31 D E
# FN
# yes
# ----------------------------------------
# Event  32 D D
# TN
# evidence since suggested despite mr
# ----------------------------------------
# Event  33 D D
# TN
# official offered scant detail missile test noting missile flew 65,000 foot 300 mile
# ----------------------------------------
# Event  34 E E
# TP
# continue support ukraine resisting threat democratic institution common democratic value principle including support free medium well countering disinformation interference democratic process
# ----------------------------------------
# Event  35 D E
# FN
# missile test latest setback u
# ----------------------------------------
# Event  36 D D
# TN
# kirby think 've long concerned china 's growing influence around world include europe
# ----------------------------------------
# Event  37 E E
# TP
# ’ almost million — seven hundred eighty-five — ’ hold exact number ’ get number — seven hundred thousand debt forgiven — whole debt forgiven work working –either teacher mean qualify
# ----------------------------------------
# Event  38 D E
# FN
# addition decided close european union airspace russian aircraft
# ----------------------------------------
# Event  39 E E
# TP
# ’ today order sustain ukraine — continues fight ’ sending congress supplemental budget request
# ----------------------------------------
# Event  40 D E
# FN
# 5 million business created last year
# ----------------------------------------
# Event  41 E E
# TP
#
# ----------------------------------------
# Event  42 E E
# TP
# however almost exhausted call — fancy phrase — “ drawdown authority ” congress authorized ukraine — authorized ukraine bipartisan spending bill last month
# ----------------------------------------
# Event  43 D D
# TN
# sylvie
# ----------------------------------------
# Event  44 E E
# TP
# look take seriously
# ----------------------------------------
# Event  45 E D
# FP
#
# ----------------------------------------
# Event  46 D D
# TN
# 's -- 's balance secretary strike every day
# ----------------------------------------
# Event  47 E E
# TP
# clarify 's case speak broadly pentagon effort send precision artillery round specifically thanks
# ----------------------------------------
# Event  48 E E
# TP
# regard food shortage yes talk food shortage
# ----------------------------------------
# Event  49 E E
# TP
# ’ not going give intelligence data number one
# ----------------------------------------
# Event  50 D D
# TN
# not firm number troop donbas
# ----------------------------------------
# Event  51 D E
# FN
# ally partner
# ----------------------------------------
# Event  52 E D
# FP
# failure came report emerged china successfully tested hypersonic glide vehicle summer shortly russia claimed successfully tested submarine-launched hypersonic missile dubbed tsirkon
# ----------------------------------------
# Event  53 E D
# FP
#
# ----------------------------------------
# Event  54 E D
# FP
# first foremost result courage ukrainian armed force
# ----------------------------------------
# Event  55 D E
# FN
# ” sullivan said u ratcheted response noting secretary defense lloyd austin paused canceled missile test despite preplanning notifying russian government
# ----------------------------------------
# Event  56 E D
# FP
# kirby well
# ----------------------------------------
# Event  57 D D
# TN
# leadership energetic capable resilient civil society partner including organization like arm control association
# ----------------------------------------
# Event  58 D D
# TN
# q thank
# ----------------------------------------
# Event  59 E E
# TP
#
# ----------------------------------------
# Event  60 D D
# TN
# 's broad agreement need support country
# ----------------------------------------
# Event  61 D D
# TN
# tomorrow nato convene summit — ’ — bring together leader 30 allied nation close partner affirm solidarity map next step take strengthen aspect nato alliance
# ----------------------------------------
# Event  62 D D
# TN
# n't read n't great relationship brit exceptionally-close intelligence-sharing process
# ----------------------------------------
# Event  63 E D
# FP
# strategic issue
# ----------------------------------------
# Event  64 E E
# TP
# president total judgment based ukraine
# ----------------------------------------
# Event  65 E D
# FP
# would foolish u throw kitchen sink not flexibility war change make change moment
# ----------------------------------------
# Event  66 D D
# TN
# land new posture include substantially force eastern part alliance higher readiness
# ----------------------------------------
# Event  67 D D
# TN
# president — mr
# ----------------------------------------
# Event  68 D D
# TN
# q training not begun mr
# ----------------------------------------
# Event  69 E E
# TP
# look report look website european external action service strategic communication team euvsdisinfo see russian medium describes happening ukraine describing president ukraine volodymyr zelenskyy
# ----------------------------------------
# Event  70 D D
# TN
# ’ got president trump calling vladimir putin smart saying no message
# ----------------------------------------
# Event  71 D D
# TN
# -based force department defense placed standby week ago
# ----------------------------------------
# Event  72 D D
# TN
# renewed land no enemy adversary son mother people land
# ----------------------------------------
# Event  73 D D
# TN
# people addition equipment
# ----------------------------------------
# Event  74 D E
# FN
# hey well wait — hold second please
# ----------------------------------------
# Event  75 D D
# TN
# able push back fight back slow russian advance
# ----------------------------------------
# Event  76 D D
# TN
# nato spokesperson ok go al jazeera
# ----------------------------------------
# Event  77 D E
# FN
# official believe chance mr
# ----------------------------------------
# Event  78 E E
# TP
# process working european friend would — would take help alleviate concern relative food shortage
# ----------------------------------------
# Event  79 E E
# TP
# urge russia withdraw completely military force equipment entire territory ukraine within internationally recognized border
# ----------------------------------------
# Event  80 D D
# TN
# q not sanction today sir not sanction today sir q mr
# ----------------------------------------
# Event  81 E D
# FP
#
# ----------------------------------------
# Event  82 D D
# TN
# tom q thanks john
# ----------------------------------------
# Event  83 D E
# FN
# 'll go back said 're monitoring every single day best
# ----------------------------------------
# Event  84 E D
# FP
# premeditated attack
# ----------------------------------------
# Event  85 D E
# FN
# putin strike nato country intentionally would not bring force military alliance bear russia also probably find facing nato troop inside ukraine artis pabriks latvia ’ defense minister told reporter traveling country month gen
# ----------------------------------------
# Event  86 E D
# FP
# met estonia also poland
# ----------------------------------------
# Event  87 E E
# TP
# ’ long tooth fool longer
# ----------------------------------------
# Event  88 D D
# TN
# ready
# ----------------------------------------
# Event  89 E D
# FP
#
# ----------------------------------------
# Event  90 D D
# TN
# ’ also spoken defense secretary austin chairman joint chief general milley preparation additional move become necessary protect nato ally support greatest military alliance history world — nato
# ----------------------------------------
# Event  91 E E
# TP
# continue supporting ukraine defending network cyber incident expand cooperation field energy security safety security nuclear material facility environmental water use issue
# ----------------------------------------
# Event  92 D D
# TN
# blinken defense secretary lloyd j
# ----------------------------------------
# Event  93 D D
# TN
# concerning unity
# ----------------------------------------
# Event  94 D D
# TN
# mean n't -- n't think 's accurate way putting
# ----------------------------------------
# Event  95 D D
# TN
# system gave nation gave helped battle kyiv helped force russian stop advance
# ----------------------------------------
# Event  96 D D
# TN
# q off-mike mr
# ----------------------------------------
# Event  97 E D
# FP
# waging peaceful country
# ----------------------------------------
# Event  98 D D
# TN
# kirby yes
# ----------------------------------------
# Event  99 D E
# FN
# part well leading alliance
# ----------------------------------------
# Event  100 E E
# TP
# presence foreign minister ukraine dmytro kuleba expressed today heart-felt solidarity ukrainian people deepest condolence victim war family
# ----------------------------------------
# Event  101 D D
# TN
# manage balance security need ukraine risk escalation light russia 's threat destroy western weapon mr
# ----------------------------------------
# Event  102 D D
# TN
# tara copp q good morning
# ----------------------------------------
# Event  103 E E
# TP
# kirby not every case
# ----------------------------------------
# Event  104 D D
# TN
# know 've seen minor movement place the…around northern part country largely 's -- 's around kyiv 're starting see repositioning
# ----------------------------------------
# Event  105 D D
# TN
# intelligence official outbreak war made harder mr
# ----------------------------------------
# Event  106 D D
# TN
# time ally agree not nato plane operating ukrainian airspace nato troop ukrainian territory
# ----------------------------------------
# Event  107 E E
# TP
# ” russian war ukraine sullivan suggested one man – russian president vladimir putin – bring brutal conflict end
# ----------------------------------------
# Event  108 E D
# FP
# six ten american saying 're feeling hardship inflation
# ----------------------------------------
# Event  109 D E
# FN
# 's beginning loosen start come pandemic huge effect ability connect people
# ----------------------------------------
# Event  110 D D
# TN
# land air sea cyber space
# ----------------------------------------
# Event  111 E D
# FP
# putin mr
# ----------------------------------------
# Event  112 E D
# FP
# wall street journal tarina tarini
# ----------------------------------------
# Event  113 D D
# TN
# 'd leave
# ----------------------------------------
# Event  114 E D
# FP
# saw flagrant violation international law attempting unilaterally create two new so-called republic sovereign ukrainian territory
# ----------------------------------------
# Event  115 D D
# TN
# -- 's believe right
# ----------------------------------------
# Event  116 E E
# TP
# n't want see russia position able
# ----------------------------------------
# Event  117 D D
# TN
# `` postponement not affect america 's nuclear deterrence way
# ----------------------------------------
# Event  118 D E
# FN
# q final question ’ heading poland tomorrow think getting firsthand look effect war million ukrainian fled country could change way might respond president ’ think ’ many many warzones
# ----------------------------------------
# Event  119 E D
# FP
# meantime ’ going help get energy liquefied natural gas whole range thing
# ----------------------------------------
# Event  120 E E
# TP
# hard work played critical role ensuring putin ’ strategic failure ukraine know know
# ----------------------------------------
# Event  121 D E
# FN
# not single russian aircraft able land take european union airfield
# ----------------------------------------
# Event  122 D E
# FN
# 'm not going speculate russia may may not system
# ----------------------------------------
# Event  123 E E
# TP
# think talk service individual case
# ----------------------------------------
# Event  124 D D
# TN
# nato ally trained ten thousand ukrainian soldier front line helped standing russia
# ----------------------------------------
# Event  125 D E
# FN
# putin asserted sanction blocking food ukraine russia getting market — sanction ’ imposed russia
# ----------------------------------------
# Event  126 E D
# FP
# according data released today general staff ukraine around 40 invading force already lost russian equipment manpower
# ----------------------------------------
# Event  127 D D
# TN
# dream clean land
# ----------------------------------------
# Event  128 D E
# FN
# ’ warzones last 15 year
# ----------------------------------------
# Event  129 E E
# TP
# “ ’ succumb nuclear blackmail ’ tolerate nuclear saber rattling nuclear brinksmanship ” said
# ----------------------------------------
# Event  130 E D
# FP
# putin ’ frequent invocation nuclear threat seen no “ practical evidence ” kind military deployment movement weapon would suggest move imminent
# ----------------------------------------
# Event  131 E E
# TP
# condemn strongest term ongoing attack civilian noncombatant systematic targeting critical infrastructure school kindergarten healthcare personnel facility well conflict-related sexual gender-based violence ukraine
# ----------------------------------------
# Event  132 E D
# FP
# cecilia ve- — vega abc
# ----------------------------------------
# Event  133 D E
# FN
# gen
# ----------------------------------------
# Event  134 E E
# TP
# constitutes blatant violation international law particular grave breach united nation charter
# ----------------------------------------
# Event  135 D D
# TN
# wanted le nato border
# ----------------------------------------
# Event  136 E E
# TP
# would respond us
# ----------------------------------------
# Event  137 E E
# TP
# `` russian defense analyst alexei ramm told kremlin-friendly newspaper izvestia view happened describing test hit `` second-stage failure
# ----------------------------------------
# Event  138 D D
# TN
# useucom ass military usefulness additional fixed wing air ukraine high-risk low gain
# ----------------------------------------
# Event  139 D D
# TN
# kirby n't
# ----------------------------------------
# Event  140 D D
# TN
# 'll go question
# ----------------------------------------
# Event  141 E E
# TP
# kirby yes no 're not going talk specific inventory level ukrainian
# ----------------------------------------
# Event  142 D D
# TN
# imposed harsher sanction earlier
# ----------------------------------------
# Event  143 D D
# TN
# believe effective way support ukrainian military fight russia provide increased amount anti-tank weapon air defense system on-going international community
# ----------------------------------------
# Event  144 E E
# TP
# 's irresponsible rhetoric
# ----------------------------------------
# Event  145 E D
# FP
# continues get pounded
# ----------------------------------------
# Event  146 D D
# TN
# around 40,000 troop direct nato command mostly eastern part alliance
# ----------------------------------------
# Event  147 D D
# TN
# mr
# ----------------------------------------
# Event  148 D D
# TN
# not go detail support ally provide many type support
# ----------------------------------------
# Event  149 D D
# TN
# 've made no bone fact past 's going gap assessment gap knowledge might see something one day next day 'll see different way 'll simply know
# ----------------------------------------
# Event  150 D D
# TN
# month working closely private — private sector harden cyber defense sharpen ability respond russian cyberattacks well
# ----------------------------------------
# Event  151 D E
# FN
# mr
# ----------------------------------------
# Event  152 D D
# TN
# 27 bloc would provide ukraine fighter jet
# ----------------------------------------
# Event  153 E D
# FP
#
# ----------------------------------------
# Event  154 D E
# FN
# return diplomat 's team yesterday lviv
# ----------------------------------------
# Event  155 D E
# FN
# act united quickly
# ----------------------------------------
# Event  156 E E
# TP
# work together stop attempt circumvent sanction aid russia mean
# ----------------------------------------
# Event  157 D D
# TN
# ukraine “ many plane already ’ fly much russian air defense
# ----------------------------------------
# Event  158 D D
# TN
# become even worse nato took action actually turned full-fledged war nato russia
# ----------------------------------------
# Event  159 E D
# FP
# number right 41
# ----------------------------------------
# Event  160 D E
# FN
# ``
# ----------------------------------------
# Event  161 E E
# TP
# shortly arrival ukraine 's deputy prime minister shmygal praised `` courage true friend ukraine ''
# ----------------------------------------
# Event  162 D D
# TN
# said training plan artillery beginning execute conclude training begun mr
# ----------------------------------------
# Event  163 D E
# FN
# however american remain detained including brittney griner paul whelan latter asked “ left behind
# ----------------------------------------
# Event  164 E E
# TP
# addition 100,000 u
# ----------------------------------------
# Event  165 D D
# TN
# talk american people want hear president
# ----------------------------------------
# Event  166 D D
# TN
# force multiplier national defence effort
# ----------------------------------------
# Event  167 D E
# FN
# ’ always respect press ’ tell much respect watching — watching zone ’ fire risking life make sure world hears truth
# ----------------------------------------
# Event  168 D E
# FN
# much disagree mr
# ----------------------------------------
# Event  169 D D
# TN
# would foolhardy
# ----------------------------------------
# Event  170 D D
# TN
# mr
# ----------------------------------------
# Event  171 D D
# TN
# “ continue consult poland nato ally issue difficult logistical challenge present not believe poland ’ proposal tenable one ” kirby pentagon spokesperson said tuesday night
# ----------------------------------------
# Event  172 E E
# TP
# thank
# ----------------------------------------
# Event  173 D D
# TN
# 2010 republican 63 seat swept control house tea party wave
# ----------------------------------------
# Event  174 D D
# TN
# n't want wrong
# ----------------------------------------
# Event  175 D E
# FN
# q sir deterrence ’ work
# ----------------------------------------
# Event  176 E E
# TP
# secretary chairman look force posture every day
# ----------------------------------------
# Event  177 D D
# TN
# would -- certainly would n't said tara ukrainian desire artillery support 're going flow additional artillery support
# ----------------------------------------
# Event  178 D D
# TN
# even -- even -- even week
# ----------------------------------------
# Event  179 E E
# TP
# ’ process taking hard look whether not going — additional debt forgiveness ’ answer next couple week
# ----------------------------------------
# Event  180 D D
# TN
# also tailor package david absorb end
# ----------------------------------------
# Event  181 D D
# TN
# needed time
# ----------------------------------------
# Event  182 D E
# FN
# “ ’ going difficult call ’ call not president entire nato council make ” mr
# ----------------------------------------
# Event  183 E D
# FP
#
# ----------------------------------------
# Event  184 E E
# TP
# look recruiting number often lag indicator lagging indicator know start really get bare metal 're well past problem set number probably going get worse
# ----------------------------------------
# Event  185 E E
# TP
# sure heck n't good people ukraine
# ----------------------------------------
# Event  186 E E
# TP
# ” u ex-marine trevor reed charged attacking police stand inside defendant cage verdict hearing moscow 's golovinsky district court july 30 2020
# ----------------------------------------
# Event  187 E E
# TP
# continue coordinate effort meet ukraine ’ urgent requirement military defence equipment
# ----------------------------------------
# Event  188 D D
# TN
# said -- pentagon briefer said yesterday mean clearly 's cause concern 's not told truth 's not -- 's misinformed think gist question n't know 's going react -- get fully informed
# ----------------------------------------
# Event  189 E E
# TP
# completed booster test series ready move forward all-up-round testing later year
# ----------------------------------------
# Event  190 E D
# FP
# putin wrong
# ----------------------------------------
# Event  191 D E
# FN
# mr
# ----------------------------------------
# Event  192 D E
# FN
# across support urgently working accelerating disbursement financial commitment ukraine
# ----------------------------------------
# Event  193 E E
# TP
# much — much new equipment ’ announced past two mon- — two week already gotten ukraine put direct use battlefield
# ----------------------------------------
# Event  194 E E
# TP
# said take seriously
# ----------------------------------------
# Event  195 E D
# FP
# little bit training switchblade 's not uav know use
# ----------------------------------------
# Event  196 D D
# TN
# 's basic timeframe 200 million president signed -- right signed -- signed 12th first delivery 18th
# ----------------------------------------
# Event  197 E D
# FP
# q sanctioning president putin president yes
# ----------------------------------------
# Event  198 D D
# TN
# nato ally partner supported ukraine equipment training many year
# ----------------------------------------
# Event  199 D E
# FN
# bravozulu usnavy 's strategic system program involved scheduled missile test flight four unarmed trident ii d5le missile successfully launched ohio-class ballistic missile submarine coast southern california
# ----------------------------------------
# Event  200 E E
# TP
# united determined strongly support ukraine producing exporting grain oil agricultural product foster coordinated initiative promote global food security address cause evolving global food crisis
# ----------------------------------------
# Event  201 D D
# TN
# kirby week ago talking ukrainian would need fight -- -- following
# ----------------------------------------
# Event  202 D D
# TN
# 're looking degree need familiarize radar system portable radar system -- 're going flow
# ----------------------------------------
# Event  203 D D
# TN
# 'm wondering know sort geographic area 20 percent kind thing senior defense official yeah referring force arrayed kyiv specifically
# ----------------------------------------
# Event  204 D D
# TN
# area ukraine literally fighting eight year
# ----------------------------------------
# Event  205 D E
# FN
# 's sacred obligation
# ----------------------------------------
# Event  206 E E
# TP
# early conversation december early january clear ’ think could sustain cohesion
# ----------------------------------------
# Event  207 E D
# FP
# sam manpad
# ----------------------------------------
# Event  208 E E
# TP
# ” country ’ leader biden president xi jinping mentioned possibility talk conversation kahl said
# ----------------------------------------
# Event  209 D E
# FN
# express concern country actor amplified russia ’ disinformation campaign
# ----------------------------------------
# Event  210 D D
# TN
# nancy q thank
# ----------------------------------------
# Event  211 D D
# TN
# must solved immediately
# ----------------------------------------
# Event  212 E E
# TP
# raising tax people everyone acknowledges — vast majority republican — ’ paying fair share
# ----------------------------------------
# Event  213 E D
# FP
# know russian tried recruit foreign fighter particularly syria
# ----------------------------------------
# Event  214 D D
# TN
# -- credible claim war crime russian force 's not dod -- whole administration least agency wherewithal provide evidence whether 's imagery -- data -- help support war crime investigation 're contributing
# ----------------------------------------
# Event  215 E D
# FP
# pentagon ’ concern moscow ’ reaction sending jet ukraine “ pure deterrence u
# ----------------------------------------
# Event  216 D D
# TN
# ca n't point given missile launch tell well know 's landed
# ----------------------------------------
# Event  217 E E
# TP
# court say ’ going
# ----------------------------------------
# Event  218 E D
# FP
# producing high risk scenario
# ----------------------------------------
# Event  219 D D
# TN
# know always stress difference wall street main street everybody seems economic pain
# ----------------------------------------
# Event  220 E E
# TP
# need pay lot attention happening
# ----------------------------------------
# Event  221 D D
# TN
# stephanopoulos donna let 's talk state union
# ----------------------------------------
# Event  222 D D
# TN
# thought could divide u home
# ----------------------------------------
# Event  223 D E
# FN
# continue explore new way isolate russia participating global market crack evasion
# ----------------------------------------
# Event  224 D D
# TN
# inflation gas price ukraine -- recognize reality bring american people tough mistake 's made maybe afghanistan place
# ----------------------------------------
# Event  225 D E
# FN
# 'm not going go beyond
# ----------------------------------------
# Event  226 E D
# FP
#
# ----------------------------------------
# Event  227 D D
# TN
# day come likely worse
# ----------------------------------------
# Event  228 D D
# TN
# minister discussed need support partner may risk
# ----------------------------------------
# Event  229 D D
# TN
# 's 're focusing
# ----------------------------------------
# Event  230 D D
# TN
# mr
# ----------------------------------------
# Event  231 D D
# TN
# minister backed ukrainian strike military target behind russian line even weapon used supplied uk
# ----------------------------------------
# Event  232 D D
# TN
# 's going talk present crisis not ukraine also inflation also 's happening gas pump
# ----------------------------------------
# Event  233 E E
# TP
# informal meeting know not take specific decision concrete action
# ----------------------------------------
# Event  234 D E
# FN
# lot nation around world meet need
# ----------------------------------------
# Event  235 D D
# TN
# already seen world ’ response
# ----------------------------------------
# Event  236 E E
# TP
# no one predicting recession
# ----------------------------------------
# Event  237 E E
# TP
# want certainly work claim fast n't want go fast miss something
# ----------------------------------------
# Event  238 D E
# FN
# n't whole lot top
# ----------------------------------------
# Event  239 D E
# FN
# activated eu civil protection mechanism 18 member state channelling critical humanitarian equipment ukraine
# ----------------------------------------
# Event  240 D D
# TN
# adding aircraft ukrainian inventory unlikely change effectiveness ukrainian air force relative russian capability
# ----------------------------------------
# Event  241 D D
# TN
# n't know whether really answered question pragmatic regarding exactly organise long nato nato ally able provide support partner need
# ----------------------------------------
# Event  242 E D
# FP
# provide — provide support ukraine ’ going continue stand together ally europe send unmistakable message defend every inch nato territory –- every single inch — united galvanized nato
# ----------------------------------------
# Event  243 D D
# TN
# consistent
# ----------------------------------------
# Event  244 E D
# FP
#
# ----------------------------------------
# Event  245 D D
# TN
# hand ukrainian pilot fighting russian invasion
# ----------------------------------------
# Event  246 D D
# TN
# n't mean anything leaving honest mistake
# ----------------------------------------
# Event  247 D D
# TN
# ukrainian begging
# ----------------------------------------
# Event  248 E E
# TP
# secretary thought useful exercise 're looking industrial base ask nation yesterday assessment defense industrial base
# ----------------------------------------
# Event  249 E E
# TP
# previously pentagon estimated chinese 200 nuclear warhead would double number 2030
# ----------------------------------------
# Event  250 E D
# FP
# obviously making decision alter goal objective
# ----------------------------------------
# Event  251 D D
# TN
# q feel ukraine continue wait pentagon -- supplier work around world contemplate moment emerge 'm asking 's different way might thinking
# ----------------------------------------
# Event  252 D D
# TN
# ’ move significant sanction emboldened
# ----------------------------------------
# Event  253 E E
# TP
# growing fight supremacy black sea weapon could used ukrainian troop recaptured strategically important snake island russia
# ----------------------------------------
# Event  254 D D
# TN
# ally north america europe sent thousand troop eastern part alliance
# ----------------------------------------
# Event  255 E D
# FP
# european command separately declared wednesday u
# ----------------------------------------
# Event  256 E E
# TP
# foreign contribution talk
# ----------------------------------------
# Event  257 E E
# TP
# ’ also going provide critical resource address food shortage around globe
# ----------------------------------------
# Event  258 E E
# TP
# congratulation entire arrw team dedication expertise got u '' said maj
# ----------------------------------------
# Event  259 D D
# TN
# foresee similar process
# ----------------------------------------
# Event  260 E D
# FP
# want say one thing see
# ----------------------------------------
# Event  261 D D
# TN
# 's russian announced going leave kyiv alone
# ----------------------------------------
# Event  262 D E
# FN
# 'm not going get ahead pending legislation
# ----------------------------------------
# Event  263 D E
# FN
# ’ situation — know different view senator scott republican want raise tax middle-class family want include half small-business owner
# ----------------------------------------
# Event  264 E D
# FP
#
# ----------------------------------------
# Event  265 D D
# TN
# 's huge problem republican party high level people break want candidate stay close donald trump order competitive affect run certainly affect win
# ----------------------------------------
# Event  266 D D
# TN
# ukrainian air force currently posse numerous mission capable aircraft flying daily
# ----------------------------------------
# Event  267 D D
# TN
# varies decide 're going -- mission 're going fly many plane want put air
# ----------------------------------------
# Event  268 D E
# FN
# interview moscow alisyn camerota “ cnn newsroom ” sullivan said “ little engagement russian government ” communication focused detained u citizen “ functioning embassy ” sharp restriction imposed russian government
# ----------------------------------------
# Event  269 D D
# TN
# let stress incredible speed scale material getting recent memory recent history truly unprecedented
# ----------------------------------------
# Event  270 E D
# FP
#
# ----------------------------------------
# Event  271 E D
# FP
# promised ’ also adding name list russian elite family member sanctioning — ’ sanctioning well
# ----------------------------------------
# Event  272 D E
# FN
# better position others give
# ----------------------------------------
# Event  273 D D
# TN
# lorne cook ap could tell little bit tasking 've given nato commander might involve looking ahead one year talking decade something longer term also use word persistent wonder mean would n't say permanent permanent basis nato secretary general way make kind decision nato politician set guideline direction task military commander give advice follow make final decision politician based advice input military commander
# ----------------------------------------
# Event  274 E E
# TP
# putin ’ war not sanction impacting harvest food disrupting movement food land sea nation around globe need
# ----------------------------------------
# Event  275 D D
# TN
# one would assume -- 're thinking even though lot left 've gone lot
# ----------------------------------------
# Event  276 D D
# TN
# evidence ground ampoule thing like
# ----------------------------------------
# Event  277 D D
# TN
# mr
# ----------------------------------------
# Event  278 D D
# TN
# break deadlock poland went hail mary
# ----------------------------------------
# Event  279 D E
# FN
# 's n't say 's no -some ship come home
# ----------------------------------------
# Event  280 D D
# TN
# 're best focus kind capability know need say want using b secondary try get system n't need lot start-up time put field almost immediately
# ----------------------------------------
# Event  281 D D
# TN
# n't happen
# ----------------------------------------
# Event  282 D E
# FN
# ’ ’ urging congress act request 22
# ----------------------------------------
# Event  283 D E
# FN
# “ mature responsible nuclear power ’ cut military military contact communication midst heightened tension
# ----------------------------------------
# Event  284 D D
# TN
# mean 's -- going family getting worst possible news dealing unspeakable grief
# ----------------------------------------
# Event  285 D D
# TN
# reason not provoke conflict prevent conflict
# ----------------------------------------
# Event  286 D D
# TN
# military territorial defense unit managed replenish arsenal equipment due many trophy took battlefield
# ----------------------------------------
# Event  287 D D
# TN
# said 've acknowledged fighting donbas going require effort side long-range fire mean side artillery
# ----------------------------------------
# Event  288 D D
# TN
# kirby wo n't get detail conversation 're putting readout
# ----------------------------------------
# Event  289 E D
# FP
# ass 're surface combatant
# ----------------------------------------
# Event  290 E D
# FP
# know sanction package specifically designed allow energy payment continue
# ----------------------------------------
# Event  291 E D
# FP
# kirby non-ukraine q off-mike
# ----------------------------------------
# Event  292 D D
# TN
# long private military contractor donbas 's not shocking u would consider adding capability
# ----------------------------------------
# Event  293 D E
# FN
# since fully-fledged war ukraine want everything support ukraine decided use capacity provide arm lethal arm lethal assistance ukrainian army value €450 million support package €50 million non-lethal supply – fuel protective equipment
# ----------------------------------------
# Event  294 D E
# FN
# step anything ’ trying nato trying day prevent ’ trying becoming undone two year thank
# ----------------------------------------
# Event  295 E E
# TP
# 're asking enough mean think question something change every hour depending rate consumption actually going battlefield
# ----------------------------------------
# Event  296 E E
# TP
# stoltenberg sounding far hawkish past said expected “ ally agree provide additional support including cybersecurity assistance equipment help ukraine protect chemical biological radiologic nuclear threat
# ----------------------------------------
# Event  297 D D
# TN
# slovakian bulgarian government told politico ’ going ship migs ukraine either
# ----------------------------------------
# Event  298 D D
# TN
# n't want leave notion -- -- deep negotiation discussion footprint predominant part discussion
# ----------------------------------------
# Event  299 E D
# FP
#
# ----------------------------------------
# Event  300 D E
# FN
# 're constantly conversation japan could look like
# ----------------------------------------
# Event  301 D D
# TN
# think matter moment
# ----------------------------------------
# Event  302 E E
# TP
# want know 's discussion could possibly offer additional permission pentagon n't already mr
# ----------------------------------------
# Event  303 D E
# FN
# signed request congress critical security economic humanitarian assistance help ukraine continue counter putin ’ aggression — pivotal moment
# ----------------------------------------
# Event  304 E D
# FP
# recently visited nato troop u troop german troop troop romania
# ----------------------------------------
# Event  305 E D
# FP
# president putin must stop war
# ----------------------------------------
# Event  306 D D
# TN
# point reporter
# ----------------------------------------
# Event  307 D D
# TN
# provided continued provide essential support ukrainian armed force
# ----------------------------------------
# Event  308 D D
# TN
# increasing presence nato force eastern part alliance deploying first time nato response force not going part conflict russia ukraine
# ----------------------------------------
# Event  309 E E
# TP
# russia aggressor
# ----------------------------------------
# Event  310 E E
# TP
# short raising specter nuclear confrontation nothing peace security region much le people ukraine
# ----------------------------------------
# Event  311 D D
# TN
# sumy poltava
# ----------------------------------------
# Event  312 D D
# TN
# yesterday finally managed organize humanitarian corridor
# ----------------------------------------
# Event  313 D E
# FN
# earlier week north korean government said japan expands military exercise united state near north korea territory north korea take retaliatory measure
# ----------------------------------------
# Event  314 E E
# TP
# built unity european — european union leading democracy g7 — g7
# ----------------------------------------
# Event  315 D D
# TN
# 's focus right
# ----------------------------------------
# Event  316 E E
# TP
# president look number one one — first thing reform system place ’ work anybody allowed people write debt engaged public service
# ----------------------------------------
# Event  317 D D
# TN
# partly scaling thing already strengthening defence security institution reform training also potentially adding activity support country
# ----------------------------------------
# Event  318 D D
# TN
# course support welcome talk negotiation taking place ukraine russia
# ----------------------------------------
# Event  319 E E
# TP
# said internal discussion administration official urging caution stake ukraine
# ----------------------------------------
# Event  320 D D
# TN
# q okay — president ’ two different thing
# ----------------------------------------
# Event  321 D D
# TN
# “ support ukrainian getting around world ’ every chance ukrainian see
# ----------------------------------------
# Event  322 E E
# TP
# 's really better question better put
# ----------------------------------------
# Event  323 D E
# FN
# 're still working way 's going look like coming month
# ----------------------------------------
# Event  324 E E
# TP
# want make sure defense industrial base continue support need well supporting effort support ukraine 's need
# ----------------------------------------
# Event  325 D D
# TN
# wonder give update status plan training europe ukrainian howitzer radar item latest package
# ----------------------------------------
# Event  326 E E
# TP
# ” putin “ probably counting u eu resolve weaken ” haines explained
# ----------------------------------------
# Event  327 E D
# FP
# need russia stop war
# ----------------------------------------
# Event  328 D D
# TN
# 26 2022 following statement attributed pentagon press secretary john kirby yesterday president authorized additional 350 million military assistance department defense inventory including anti-armor small arm various munition body armor related equipment support ukraine ’ front-line defender facing russia ’ unprovoked attack
# ----------------------------------------
# Event  329 D E
# FN
# kirby n't
# ----------------------------------------
# Event  330 E E
# TP
# want announce tomorrow secretary welcoming canadian counterpart canadian minister national defense anita anand pentagon
# ----------------------------------------
# Event  331 D D
# TN
# today
# ----------------------------------------
# Event  332 D D
# TN
# 're fighting bravely
# ----------------------------------------
# Event  333 E E
# TP
# fear russia likely use weapon precisely erode distinction conventional nuclear arm
# ----------------------------------------
# Event  334 D E
# FN
# kirby 'm not aware need guidance secretary
# ----------------------------------------
# Event  335 D D
# TN
# democrat facing real headwind heading midterm
# ----------------------------------------
# Event  336 E E
# TP
#
# ----------------------------------------
# Event  337 E D
# FP
#
# ----------------------------------------
# Event  338 E D
# FP
# “ along nation continue send weapon know ’ used great effect
# ----------------------------------------
# Event  339 D E
# FN
# think 's proof right kind system provided ukraine effect inability self-defense need
# ----------------------------------------
# Event  340 D D
# TN
# n't shipment speak today think 'll see move soon well -- ammunition go
# ----------------------------------------
# Event  341 E D
# FP
# n't know whether actually achieved goal close got many foreign fighter might ukraine n't good count
# ----------------------------------------
# Event  342 E D
# FP
# prepositioned equipment supply
# ----------------------------------------
# Event  343 D D
# TN
# president zelensky since beginning -- want close loop
# ----------------------------------------
# Event  344 E D
# FP
# ” u military ’ responsibility “ provide president option
# ----------------------------------------
# Event  345 D D
# TN
# even lower end hypersonic range – 3,800 mile per hour – flight 300 mile le 5 minute
# ----------------------------------------
# Event  346 D E
# FN
# president no ’ not thanking
# ----------------------------------------
# Event  347 E E
# TP
#
# ----------------------------------------
# Event  348 D D
# TN
# get united nato
# (80, 155, 57, 57)

# %%
def calculate_f1_score(tp, tn, fp, fn):
    if tp+fp == 0:
      precision = 0.0
    else:
      precision = tp / (tp + fp)
    
    if tp+fn == 0:
      recall = 0.0
    else:
      recall = tp / (tp + fn)
    if precision + recall == 0:
      f1_score = 0.0
    else:
      f1_score = 2 * (precision * recall) / (precision + recall)
    return f1_score

def calculate_accuracy(tp, tn, fp, fn):
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    return accuracy

print("F1: ", calculate_f1_score(tp, tn, fp, fn))
print("Accuracy: ", calculate_accuracy(tp, tn, fp, fn))
# Out:
# F1:  0.583941605839416
# Accuracy:  0.673352435530086

# %% [markdown]
# #Top words associated with each class

# %%
import pandas as pd
import re

df = nuclear_threat
# Assuming 'df' is your dataframe and 'text_column' is the column containing the text data
text_data = ' '.join(df['text'].astype(str).tolist())

# Tokenize the text into individual words
tokens = nltk.word_tokenize(text_data)

# Generate ngrams from the tokens
bigrams = nltk.ngrams(tokens, 2)

# Get unique bigrams using a set
unique_bigrams = set(bigrams)

# Convert the set back to a list
unique_bigrams_list = list(unique_bigrams)
unique_bigrams_list = [" ".join(b) for b in unique_bigrams]

texts = unique_bigrams_list
docs = [nlp.tokenizer(text) for text in texts]

# Use textcat to get the scores for each doc
if assume:
  textcat = nlp.get_pipe('textcat')
else:
  textcat = nlp.get_pipe('textcat_multilabel')
scores = textcat.predict(docs)

dictionary = {k: v[0] for k, v in zip(texts, scores)}

sorted_dict = dict(sorted(dictionary.items(), key=lambda x: x[1],reverse=True))

top_k = 20
i = 0
for key, value in sorted_dict.items():
    print(key, value)
    i+=1
    if i == top_k:
      break
# Out:
# zelensky participate 1.0
# straight answer 1.0
# really answer 1.0
# invade surely 0.9999999
# union demonstrate 0.9999999
# answer think 0.9999999
# test series 0.9999999
# protect refugee 0.9999999
# production certain 0.9999999
# month demonstrate 0.9999999
# ukraine destroyed 0.9999999
# border express 0.9999999
# ukraine record 0.9999999
# legislative process 0.99999976
# significant timely 0.99999976
# redeployment yet 0.99999976
# say answer 0.99999976
# southern border 0.99999976
# debate public 0.99999976
# integration refugee 0.99999976
